# %% [markdown]
# # Car Make and Model Recognizer
# I shall explore here my tries to reach a good optimizer

# %% [markdown]
# ## Importing Libraries

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense, BatchNormalization, Activation, PReLU
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from glob import glob
from keras import regularizers
from keras.layers.advanced_activations import PReLU
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Pre-Processing
#
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.25,
                                   rotation_range = 90,
                                   horizontal_flip=True,
                                  validation_split = 0.3)
#test_datagen = ImageDataGenerator(rescale=1./255,
 #                                horizontal_flip = True)

train_data = train_datagen.flow_from_directory('My_Cars/trainCropped',
                                              target_size=(128, 128),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='training')
test_data = train_datagen.flow_from_directory('My_Cars/trainCropped',
                                              target_size=(128, 128),
                                              batch_size=32,
                                              class_mode='categorical',
                                            subset='validation')
# Out:
# Found 5796 images belonging to 196 classes.
# Found 2348 images belonging to 196 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()


### TODO: Define your architecture.
model.add(Conv2D(filters=32, kernel_size=4, strides=1,kernel_initializer = 'random_normal', padding='same', input_shape=(128, 128, 3)))
model.add(BatchNormalization())
model.add(PReLU())
#act = PReLU(weights=None, alpha_initializer="zero")
#model.add(act)
model.add(MaxPooling2D(pool_size=2, strides=2))

model.add(Conv2D(filters=128, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same')) 
model.add(BatchNormalization())
#model.add(Activation("relu"))
model.add(PReLU())
model.add(MaxPooling2D(pool_size=2, strides=2))

model.add(Conv2D(filters=256, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same'))
model.add(BatchNormalization())
#model.add(Activation("relu"))
model.add(PReLU())
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Dropout(0.5))

model.add(Conv2D(filters=512, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same'))
model.add(BatchNormalization())
#model.add(Activation("relu"))
model.add(PReLU())
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Dropout(0.5))

model.add(Conv2D(filters=512, kernel_size=2, strides=1,kernel_initializer = 'random_normal',padding='same'))
model.add(BatchNormalization())
#model.add(Activation("relu"))
model.add(PReLU())
model.add(MaxPooling2D(pool_size=2, strides=2))

model.add(GlobalAveragePooling2D())

model.add(Dense(196, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      1568
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 128, 128, 32)      524288
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 64, 64, 128)       524288
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 32, 32, 256)       262144
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 512)       524800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 16, 16, 512)       131072
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 512)         1049088
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# p_re_lu_5 (PReLU)            (None, 8, 8, 512)         32768
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 3,304,164
# Trainable params: 3,301,284
# Non-trainable params: 2,880
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='Saved_Models/weights.best.from_scratch36.hdf5', 
                               verbose=1, save_best_only=True)

Saving = model.fit_generator(train_data,
          steps_per_epoch=182,  
          epochs=epochs,
          verbose=1, 
          validation_data=test_data,
          validation_steps=74,
          callbacks=[checkpointer])
# model.fit(train_data, test_data,
#                   callbacks = [checkpointer],
#                   validation_split = 0.33,
#                   epochs=epochs,
#           batch_size = 20,
#           verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 182/182 [==============================] - 63s 348ms/step - loss: 5.4421 - acc: 0.0101 - val_loss: 5.6988 - val_acc: 0.0124
#
# Epoch 00001: val_loss improved from inf to 5.69883, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch
saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 17/100
# 182/182 [==============================] - 60s 330ms/step - loss: 4.2795 - acc: 0.0977 - val_loss: 5.7124 - val_acc: 0.0400
#
# Epoch 00017: val_loss did not improve from 4.85268
# Epoch 18/100
# 182/182 [==============================] - 60s 331ms/step - loss: 4.2315 - acc: 0.1010 - val_loss: 5.5112 - val_acc: 0.0388
#
# Epoch 00018: val_loss did not improve from 4.85268
# Epoch 19/100
# 182/182 [==============================] - 62s 340ms/step - loss: 4.1650 - acc: 0.1106 - val_loss: 4.7907 - val_acc: 0.0592
#
# Epoch 00019: val_loss improved from 4.85268 to 4.79066, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 20/100
# 182/182 [==============================] - 62s 342ms/step - loss: 4.1343 - acc: 0.1133 - val_loss: 5.8434 - val_acc: 0.0439
#
# Epoch 00020: val_loss did not improve from 4.79066
# Epoch 21/100
# 182/182 [==============================] - 63s 347ms/step - loss: 4.0819 - acc: 0.1223 - val_loss: 4.8041 - val_acc: 0.0652
#
# Epoch 00021: val_loss did not improve from 4.79066
# Epoch 22/100
# 182/182 [==============================] - 68s 371ms/step - loss: 4.0209 - acc: 0.1329 - val_loss: 5.6116 - val_acc: 0.0473
#
# Epoch 00022: val_loss did not improve from 4.79066
# Epoch 23/100
# 182/182 [==============================] - 64s 349ms/step - loss: 3.9913 - acc: 0.1348 - val_loss: 4.5074 - val_acc: 0.0784
#
# Epoch 00023: val_loss improved from 4.79066 to 4.50736, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 24/100
# 182/182 [==============================] - 62s 340ms/step - loss: 3.9357 - acc: 0.1447 - val_loss: 6.8016 - val_acc: 0.0273
#
# Epoch 00024: val_loss did not improve from 4.50736
# Epoch 25/100
# 182/182 [==============================] - 60s 331ms/step - loss: 3.8800 - acc: 0.1513 - val_loss: 7.3337 - val_acc: 0.0277
#
# Epoch 00025: val_loss did not improve from 4.50736
# Epoch 26/100
# 182/182 [==============================] - 62s 343ms/step - loss: 3.8335 - acc: 0.1590 - val_loss: 4.9103 - val_acc: 0.0558
#
# Epoch 00026: val_loss did not improve from 4.50736
# Epoch 27/100
# 182/182 [==============================] - 62s 341ms/step - loss: 3.7736 - acc: 0.1681 - val_loss: 6.4803 - val_acc: 0.0383
#
# Epoch 00027: val_loss did not improve from 4.50736
# Epoch 28/100
# 182/182 [==============================] - 61s 336ms/step - loss: 3.7361 - acc: 0.1717 - val_loss: 4.4954 - val_acc: 0.0899
#
# Epoch 00028: val_loss improved from 4.50736 to 4.49538, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 29/100
# 182/182 [==============================] - 60s 330ms/step - loss: 3.6817 - acc: 0.1782 - val_loss: 4.4032 - val_acc: 0.1116
#
# Epoch 00029: val_loss improved from 4.49538 to 4.40324, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 30/100
# 182/182 [==============================] - 60s 327ms/step - loss: 3.6523 - acc: 0.1858 - val_loss: 6.8520 - val_acc: 0.0430
#
# Epoch 00030: val_loss did not improve from 4.40324
# Epoch 31/100
# 182/182 [==============================] - 59s 322ms/step - loss: 3.6047 - acc: 0.1868 - val_loss: 4.7759 - val_acc: 0.0869
#
# Epoch 00031: val_loss did not improve from 4.40324
# Epoch 32/100
# 182/182 [==============================] - 57s 314ms/step - loss: 3.5575 - acc: 0.1956 - val_loss: 5.8554 - val_acc: 0.0596
#
# Epoch 00032: val_loss did not improve from 4.40324
# Epoch 33/100
saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 50/100
# 182/182 [==============================] - 61s 338ms/step - loss: 2.8237 - acc: 0.3221 - val_loss: 5.0072 - val_acc: 0.0890
#
# Epoch 00050: val_loss did not improve from 4.28638
# Epoch 51/100
# 182/182 [==============================] - 61s 334ms/step - loss: 2.7745 - acc: 0.3302 - val_loss: 4.2455 - val_acc: 0.1384
#
# Epoch 00051: val_loss improved from 4.28638 to 4.24551, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 52/100
# 182/182 [==============================] - 60s 329ms/step - loss: 2.7243 - acc: 0.3427 - val_loss: 4.4212 - val_acc: 0.1278
#
# Epoch 00052: val_loss did not improve from 4.24551
# Epoch 53/100
# 182/182 [==============================] - 60s 328ms/step - loss: 2.6846 - acc: 0.3510 - val_loss: 4.9166 - val_acc: 0.0967
#
# Epoch 00053: val_loss did not improve from 4.24551
# Epoch 54/100
# 182/182 [==============================] - 59s 326ms/step - loss: 2.6512 - acc: 0.3558 - val_loss: 4.0169 - val_acc: 0.1546
#
# Epoch 00054: val_loss improved from 4.24551 to 4.01691, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 55/100
# 182/182 [==============================] - 60s 328ms/step - loss: 2.5998 - acc: 0.3606 - val_loss: 5.1229 - val_acc: 0.0980
#
# Epoch 00055: val_loss did not improve from 4.01691
# Epoch 56/100
# 182/182 [==============================] - 59s 326ms/step - loss: 2.5705 - acc: 0.3776 - val_loss: 4.9175 - val_acc: 0.0992
#
# Epoch 00056: val_loss did not improve from 4.01691
# Epoch 57/100
# 182/182 [==============================] - 60s 331ms/step - loss: 2.5599 - acc: 0.3719 - val_loss: 3.9773 - val_acc: 0.1772
#
# Epoch 00057: val_loss improved from 4.01691 to 3.97732, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 58/100
# 182/182 [==============================] - 64s 351ms/step - loss: 2.5214 - acc: 0.3829 - val_loss: 4.0276 - val_acc: 0.1542
#
# Epoch 00058: val_loss did not improve from 3.97732
# Epoch 59/100
# 182/182 [==============================] - 61s 336ms/step - loss: 2.4749 - acc: 0.3827 - val_loss: 5.6920 - val_acc: 0.0873
#
# Epoch 00059: val_loss did not improve from 3.97732
# Epoch 60/100
# 182/182 [==============================] - 59s 323ms/step - loss: 2.4776 - acc: 0.3922 - val_loss: 4.7318 - val_acc: 0.1039
#
# Epoch 00060: val_loss did not improve from 3.97732
# Epoch 61/100
# 182/182 [==============================] - 60s 330ms/step - loss: 2.4015 - acc: 0.4049 - val_loss: 4.0361 - val_acc: 0.1593
#
# Epoch 00061: val_loss did not improve from 3.97732
# Epoch 62/100
# 182/182 [==============================] - 62s 341ms/step - loss: 2.3538 - acc: 0.4171 - val_loss: 4.2272 - val_acc: 0.1525
#
# Epoch 00062: val_loss did not improve from 3.97732
# Epoch 63/100
# 182/182 [==============================] - 63s 346ms/step - loss: 2.3647 - acc: 0.4097 - val_loss: 4.1213 - val_acc: 0.1729
#
# Epoch 00063: val_loss did not improve from 3.97732
# Epoch 64/100
# 182/182 [==============================] - 63s 343ms/step - loss: 2.3386 - acc: 0.4222 - val_loss: 3.8439 - val_acc: 0.1831
#
# Epoch 00064: val_loss improved from 3.97732 to 3.84386, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 65/100
# 182/182 [==============================] - 61s 334ms/step - loss: 2.3016 - acc: 0.4287 - val_loss: 6.0161 - val_acc: 0.0745
#
# Epoch 00065: val_loss did not improve from 3.84386
# Epoch 66/100
# 182/182 [==============================] - 61s 337ms/step - loss: 2.2700 - acc: 0.4339 - val_loss: 4.2443 - val_acc: 0.1478
#
# Epoch 00066: val_loss did not improve from 3.84386
# Epoch 67/100
# 182/182 [==============================] - 58s 317ms/step - loss: 2.2330 - acc: 0.4459 - val_loss: 5.0703 - val_acc: 0.1367
#
# Epoch 00067: val_loss did not improve from 3.84386
# Epoch 68/100
# 182/182 [==============================] - 57s 315ms/step - loss: 2.2062 - acc: 0.4442 - val_loss: 4.1887 - val_acc: 0.1537
#
# Epoch 00068: val_loss did not improve from 3.84386
# Epoch 69/100
# 182/182 [==============================] - 57s 314ms/step - loss: 2.1801 - acc: 0.4512 - val_loss: 3.7918 - val_acc: 0.1968
#
# Epoch 00069: val_loss improved from 3.84386 to 3.79176, saving model to Saved_Models/weights.best.from_scratch36.hdf5
# Epoch 70/100
# 182/182 [==============================] - 57s 315ms/step - loss: 2.1227 - acc: 0.4602 - val_loss: 6.0052 - val_acc: 0.0856
#
# Epoch 00070: val_loss did not improve from 3.79176
# Epoch 71/100
# 182/182 [==============================] - 57s 315ms/step - loss: 2.1110 - acc: 0.4670 - val_loss: 3.9526 - val_acc: 0.1780
#
# Epoch 00071: val_loss did not improve from 3.79176
# Epoch 72/100
# 182/182 [==============================] - 57s 315ms/step - loss: 2.0801 - acc: 0.4694 - val_loss: 4.1429 - val_acc: 0.1640
#
# Epoch 00072: val_loss did not improve from 3.79176
# Epoch 73/100
# 182/182 [==============================] - 57s 315ms/step - loss: 2.0604 - acc: 0.4700 - val_loss: 5.2348 - val_acc: 0.1171
#
# Epoch 00073: val_loss did not improve from 3.79176
# Epoch 74/100
# 182/182 [==============================] - 57s 314ms/step - loss: 2.0497 - acc: 0.4772 - val_loss: 3.9153 - val_acc: 0.1895
#
# Epoch 00074: val_loss did not improve from 3.79176
# Epoch 75/100
# 182/182 [==============================] - 57s 314ms/step - loss: 2.0101 - acc: 0.4845 - val_loss: 5.2514 - val_acc: 0.1154
#
# Epoch 00075: val_loss did not improve from 3.79176
# Epoch 76/100
# 182/182 [==============================] - 57s 316ms/step - loss: 1.9972 - acc: 0.4885 - val_loss: 4.5584 - val_acc: 0.1401
#
# Epoch 00076: val_loss did not improve from 3.79176
# Epoch 77/100
# 182/182 [==============================] - 58s 316ms/step - loss: 1.9617 - acc: 0.4990 - val_loss: 4.5570 - val_acc: 0.1418
#
# Epoch 00077: val_loss did not improve from 3.79176
# Epoch 78/100
# 182/182 [==============================] - 57s 314ms/step - loss: 1.9152 - acc: 0.5043 - val_loss: 4.0347 - val_acc: 0.1806
#
# Epoch 00078: val_loss did not improve from 3.79176
# Epoch 79/100
# 182/182 [==============================] - 57s 314ms/step - loss: 1.9269 - acc: 0.4991 - val_loss: 7.0641 - val_acc: 0.0865
#
# Epoch 00079: val_loss did not improve from 3.79176
# Epoch 80/100
# 182/182 [==============================] - 58s 316ms/step - loss: 1.8755 - acc: 0.5131 - val_loss: 3.8296 - val_acc: 0.2066
# Epoch 00080: val_loss did not improve from 3.79176
# Epoch 81/100
# 182/182 [==============================] - 57s 314ms/step - loss: 1.8436 - acc: 0.5203 - val_loss: 6.3377 - val_acc: 0.0822
#
# Epoch 00081: val_loss did not improve from 3.79176
# Epoch 82/100
# 182/182 [==============================] - 57s 315ms/step - loss: 1.8334 - acc: 0.5239 - val_loss: 4.4313 - val_acc: 0.1397
#
# Epoch 00082: val_loss did not improve from 3.79176
# Epoch 83/100
# 182/182 [==============================] - 57s 316ms/step - loss: 1.8370 - acc: 0.5162 - val_loss: 5.0933 - val_acc: 0.1354
#
# Epoch 00083: val_loss did not improve from 3.79176
# Epoch 84/100
# 182/182 [==============================] - 57s 315ms/step - loss: 1.7867 - acc: 0.5347 - val_loss: 3.9466 - val_acc: 0.1955
#
# Epoch 00084: val_loss did not improve from 3.79176
# Epoch 85/100
# 182/182 [==============================] - 57s 315ms/step - loss: 1.7765 - acc: 0.5354 - val_loss: 4.3418 - val_acc: 0.1448
#
# Epoch 00085: val_loss did not improve from 3.79176
# Epoch 86/100
# 182/182 [==============================] - 57s 315ms/step - loss: 1.7245 - acc: 0.5400 - val_loss: 6.4840 - val_acc: 0.0750
#
# Epoch 00086: val_loss did not improve from 3.79176
# Epoch 87/100
# 182/182 [==============================] - 59s 326ms/step - loss: 1.7345 - acc: 0.5385 - val_loss: 5.0426 - val_acc: 0.1201
#
# Epoch 00087: val_loss did not improve from 3.79176
# Epoch 88/100
# 182/182 [==============================] - 61s 332ms/step - loss: 1.7181 - acc: 0.5436 - val_loss: 5.0459 - val_acc: 0.1410
#
# Epoch 00088: val_loss did not improve from 3.79176
# Epoch 89/100
# 182/182 [==============================] - 60s 330ms/step - loss: 1.6705 - acc: 0.5665 - val_loss: 4.5619 - val_acc: 0.1525
#
# Epoch 00089: val_loss did not improve from 3.79176
# Epoch 90/100
# 182/182 [==============================] - 60s 331ms/step - loss: 1.6523 - acc: 0.5517 - val_loss: 4.6649 - val_acc: 0.1393
#
# Epoch 00090: val_loss did not improve from 3.79176
# Epoch 91/100
# 182/182 [==============================] - 60s 332ms/step - loss: 1.6363 - acc: 0.5682 - val_loss: 4.1774 - val_acc: 0.1589
#
# Epoch 00091: val_loss did not improve from 3.79176
# Epoch 92/100
# 182/182 [==============================] - 64s 350ms/step - loss: 1.6233 - acc: 0.5750 - val_loss: 4.3255 - val_acc: 0.1742
#
# Epoch 00092: val_loss did not improve from 3.79176
# Epoch 93/100
# 182/182 [==============================] - 65s 357ms/step - loss: 1.6183 - acc: 0.5737 - val_loss: 3.9647 - val_acc: 0.1904
#
# Epoch 00093: val_loss did not improve from 3.79176
# Epoch 94/100
# 182/182 [==============================] - 62s 343ms/step - loss: 1.5819 - acc: 0.5752 - val_loss: 4.7728 - val_acc: 0.1397
#
# Epoch 00094: val_loss did not improve from 3.79176
# Epoch 95/100
# 182/182 [==============================] - 61s 333ms/step - loss: 1.5501 - acc: 0.5817 - val_loss: 4.2591 - val_acc: 0.1635
#
# Epoch 00095: val_loss did not improve from 3.79176
# Epoch 96/100
# 182/182 [==============================] - 60s 332ms/step - loss: 1.5504 - acc: 0.5927 - val_loss: 3.9224 - val_acc: 0.2176
#
# Epoch 00096: val_loss did not improve from 3.79176
# Epoch 97/100
# 182/182 [==============================] - 59s 325ms/step - loss: 1.5044 - acc: 0.5967 - val_loss: 5.1578 - val_acc: 0.1435
#
# Epoch 00097: val_loss did not improve from 3.79176
# Epoch 98/100
# 182/182 [==============================] - 60s 330ms/step - loss: 1.4813 - acc: 0.6039 - val_loss: 5.1690 - val_acc: 0.1482
#
# Epoch 00098: val_loss did not improve from 3.79176
# Epoch 99/100
# 182/182 [==============================] - 61s 336ms/step - loss: 1.4861 - acc: 0.6020 - val_loss: 4.0079 - val_acc: 0.2040
#
# Epoch 00099: val_loss did not improve from 3.79176
# Epoch 100/100
# 182/182 [==============================] - 60s 329ms/step - loss: 1.4415 - acc: 0.6159 - val_loss: 4.5782 - val_acc: 0.1691
#
# Epoch 00100: val_loss did not improve from 3.79176

# %%
vals = pd.DataFrame.from_dict(Saving.history)
vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
vals.head(n=31)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7236ed9c2b3a> in <module>
#       1
# ----> 2 vals = pd.DataFrame.from_dict(Saving.history)
#       3 vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
#       4 vals.head(n=31)
#
# NameError: name 'pd' is not defined

# %%
import seaborn as sns
sns.set_style({'xtick.bottom':False,
               'ytick.left':False,
               'axes.spines.bottom': False,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False})

ig,(ax,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(20,20))
sns.scatterplot(x='epochs',y='acc',data=vals,ax=ax,color='r')
sns.lineplot(x='epochs',y='val_acc',data=vals,ax=ax,color='g')
sns.scatterplot(x='epochs',y='loss',data=vals,ax=ax1,color='r')
sns.lineplot(x='epochs',y='val_loss',data=vals,ax=ax1,color='g')
ax.legend(labels=['Test Accuracy','Training Accuracy'])
ax1.legend(labels=['Test Loss','Training Loss'])

# %%
# for i in range(n_iterations):
#         print('\r{}/{}'. format(i, n_iterations))
#         #initilaize random hyperparameters
#         random_parameters = {K: random.sample(V, 1)[0] for K, V in parameters_grid.items()}
#         #create model with random hyperparameters
#         model = create_model(random_parameters)
#         opt = create_RMSprop_optimizer(random_parameters)
#         #compile model
#         model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])
#         #train model
#         epochs = 40
#         checkpointer = ModelCheckpoint(filepath='saved_models/model_weights.hdf5', verbose=1, save_best_only=True)
#         early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 8)
#         history = model.fit(X_train, Y_train,
#                   callbacks = [checkpointer, early_stopping],
#                   validation_split = 0.33,
#                   epochs=epochs, batch_size = 20, verbose=1)
#         #compare current min validation loss with global min validation loss
#         current_min_val_loss = np.min(history.history['val_loss'])
#         if(current_min_val_loss < global_min_val_loss):
#             global_min_val_loss = current_min_val_loss
#             #save the best model so far
#             model.load_weights('saved_models/model_weights.hdf5')
#             model.save('saved_models/best_model.h5')
#             print('saving new best model, val_loss = {}'.format(current_min_val_loss))
#             #save best hyperparameters
#             best_hyperparameters = random_parameters
