# %% [markdown]
# # Car Make and Model Recognizer
# I shall explore here my tries to reach a good optimizer

# %% [markdown]
# ## Importing Libraries

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from glob import glob

# %% [markdown]
# ## Pre-Processing
#
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.25,
                                   rotation_range = 90,
                                   horizontal_flip=True,
                                  validation_split = 0.3)
#test_datagen = ImageDataGenerator(rescale=1./255,
 #                                horizontal_flip = True)

train_data = train_datagen.flow_from_directory('My_Cars/train',
                                              target_size=(256,256),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='training')
test_data = train_datagen.flow_from_directory('My_Cars/train',
                                              target_size=(256,256),
                                              batch_size=32,
                                              class_mode='categorical',
                                            subset='validation',
                                            shuffle=True)
# Out:
# Found 5796 images belonging to 196 classes.
# Found 2348 images belonging to 196 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()

#First Layer
model.add(Conv2D(filters=32, kernel_size=6,padding='same', input_shape=(256, 256, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(BatchNormalization())
model.add(Dropout(0.25))
#Second Layer
model.add(Conv2D(filters=64, kernel_size=6, activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(BatchNormalization())
model.add(Dropout(0.25))
#Third Layer
model.add(Conv2D(filters=128, kernel_size=6, activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(Dropout(0.25))
model.add(BatchNormalization())
#Fourth Layer
model.add(Conv2D(filters=128, kernel_size=6,padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(Dropout(0.25))


#Last Layer
#model.add(Flatten())

model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(196, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 256, 256, 32)      3488
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 59, 59, 64)        73792
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 10, 128)       295040
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 128)         589952
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1, 1, 512)         66048
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 1, 1, 512)         262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 1,396,516
# Trainable params: 1,394,020
# Non-trainable params: 2,496
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 1000

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='Saved_Models/weights.best.from_scratch22.hdf5', 
                               verbose=1, save_best_only=True)

Saving = model.fit_generator(train_data,
          steps_per_epoch=200,  
          epochs=epochs,
          verbose=1, 
          validation_data=test_data,
          validation_steps=100,
          callbacks=[checkpointer])
# model.fit(train_data, test_data,
#                   callbacks = [checkpointer],
#                   validation_split = 0.33,
#                   epochs=epochs,
#           batch_size = 20,
#           verbose=1)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 209s 1s/step - loss: 5.7189 - acc: 0.0075 - val_loss: 8.6778 - val_acc: 0.0069
#
# Epoch 00001: val_loss improved from inf to 8.67777, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 2/1000
# 200/200 [==============================] - 214s 1s/step - loss: 5.3978 - acc: 0.0130 - val_loss: 6.5599 - val_acc: 0.0119
#
# Epoch 00002: val_loss improved from 8.67777 to 6.55991, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 3/1000
# 200/200 [==============================] - 209s 1s/step - loss: 5.2996 - acc: 0.0136 - val_loss: 5.7156 - val_acc: 0.0057
#
# Epoch 00003: val_loss improved from 6.55991 to 5.71562, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 4/1000
# 200/200 [==============================] - 213s 1s/step - loss: 5.2398 - acc: 0.0138 - val_loss: 5.4736 - val_acc: 0.0113
#
# Epoch 00004: val_loss improved from 5.71562 to 5.47362, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 5/1000
# 200/200 [==============================] - 220s 1s/step - loss: 5.1770 - acc: 0.0184 - val_loss: 5.3568 - val_acc: 0.0160
#
# Epoch 00005: val_loss improved from 5.47362 to 5.35683, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 6/1000
# 200/200 [==============================] - 211s 1s/step - loss: 5.1058 - acc: 0.0239 - val_loss: 5.3117 - val_acc: 0.0225
#
# Epoch 00006: val_loss improved from 5.35683 to 5.31172, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 7/1000
# 200/200 [==============================] - 223s 1s/step - loss: 5.0767 - acc: 0.0238 - val_loss: 5.1739 - val_acc: 0.0226
#
# Epoch 00007: val_loss improved from 5.31172 to 5.17387, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 8/1000
# 200/200 [==============================] - 210s 1s/step - loss: 5.0124 - acc: 0.0292 - val_loss: 5.2125 - val_acc: 0.0223
#
# Epoch 00008: val_loss did not improve from 5.17387
# Epoch 9/1000
# 200/200 [==============================] - 217s 1s/step - loss: 5.0016 - acc: 0.0270 - val_loss: 5.1982 - val_acc: 0.0291
#
# Epoch 00009: val_loss did not improve from 5.17387
# Epoch 10/1000
# 200/200 [==============================] - 225s 1s/step - loss: 4.9409 - acc: 0.0334 - val_loss: 5.2789 - val_acc: 0.0233
#
# Epoch 00010: val_loss did not improve from 5.17387
# Epoch 11/1000
# 200/200 [==============================] - 223s 1s/step - loss: 4.8941 - acc: 0.0397 - val_loss: 5.2256 - val_acc: 0.0201
#
# Epoch 00011: val_loss did not improve from 5.17387
# Epoch 12/1000
# 200/200 [==============================] - 223s 1s/step - loss: 4.8710 - acc: 0.0408 - val_loss: 5.1526 - val_acc: 0.0212
#
# Epoch 00012: val_loss improved from 5.17387 to 5.15257, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 13/1000
# 200/200 [==============================] - 213s 1s/step - loss: 4.8215 - acc: 0.0458 - val_loss: 5.1396 - val_acc: 0.0280
#
# Epoch 00013: val_loss improved from 5.15257 to 5.13960, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 14/1000
# 200/200 [==============================] - 216s 1s/step - loss: 4.7880 - acc: 0.0472 - val_loss: 5.1053 - val_acc: 0.0286
#
# Epoch 00014: val_loss improved from 5.13960 to 5.10533, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 15/1000
# 200/200 [==============================] - 221s 1s/step - loss: 4.7590 - acc: 0.0459 - val_loss: 5.0758 - val_acc: 0.0310
#
# Epoch 00015: val_loss improved from 5.10533 to 5.07578, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 16/1000
# 200/200 [==============================] - 226s 1s/step - loss: 4.7089 - acc: 0.0509 - val_loss: 5.0747 - val_acc: 0.0343
#
# Epoch 00016: val_loss improved from 5.07578 to 5.07466, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 17/1000
# 200/200 [==============================] - 219s 1s/step - loss: 4.6912 - acc: 0.0534 - val_loss: 5.1721 - val_acc: 0.0308
#
# Epoch 00017: val_loss did not improve from 5.07466
# Epoch 18/1000
# 200/200 [==============================] - 193s 964ms/step - loss: 4.6335 - acc: 0.0623 - val_loss: 5.0402 - val_acc: 0.0348
#
# Epoch 00018: val_loss improved from 5.07466 to 5.04024, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 19/1000
# 200/200 [==============================] - 190s 951ms/step - loss: 4.6173 - acc: 0.0558 - val_loss: 5.1384 - val_acc: 0.0283
#
# Epoch 00019: val_loss did not improve from 5.04024
# Epoch 20/1000
# 200/200 [==============================] - 184s 920ms/step - loss: 4.5918 - acc: 0.0633 - val_loss: 5.1151 - val_acc: 0.0408
#
# Epoch 00020: val_loss did not improve from 5.04024
# Epoch 21/1000
# 200/200 [==============================] - 186s 928ms/step - loss: 4.5504 - acc: 0.0673 - val_loss: 5.0993 - val_acc: 0.0330
#
# Epoch 00021: val_loss did not improve from 5.04024
# Epoch 22/1000
# 200/200 [==============================] - 186s 929ms/step - loss: 4.4805 - acc: 0.0752 - val_loss: 5.0552 - val_acc: 0.0365
#
# Epoch 00022: val_loss did not improve from 5.04024
# Epoch 23/1000
# 200/200 [==============================] - 185s 923ms/step - loss: 4.4911 - acc: 0.0692 - val_loss: 5.0819 - val_acc: 0.0354
#
# Epoch 00023: val_loss did not improve from 5.04024
# Epoch 24/1000
# 200/200 [==============================] - 187s 934ms/step - loss: 4.4306 - acc: 0.0756 - val_loss: 5.0286 - val_acc: 0.0393
#
# Epoch 00024: val_loss improved from 5.04024 to 5.02861, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 25/1000
# 200/200 [==============================] - 188s 940ms/step - loss: 4.4258 - acc: 0.0777 - val_loss: 5.0778 - val_acc: 0.0365
#
# Epoch 00025: val_loss did not improve from 5.02861
# Epoch 26/1000
# 200/200 [==============================] - 187s 936ms/step - loss: 4.3914 - acc: 0.0828 - val_loss: 5.0546 - val_acc: 0.0367
#
# Epoch 00026: val_loss did not improve from 5.02861
# Epoch 27/1000
# 200/200 [==============================] - 186s 931ms/step - loss: 4.3784 - acc: 0.0834 - val_loss: 5.0899 - val_acc: 0.0336
#
# Epoch 00027: val_loss did not improve from 5.02861
# Epoch 28/1000
# 200/200 [==============================] - 188s 940ms/step - loss: 4.3305 - acc: 0.0906 - val_loss: 5.0142 - val_acc: 0.0387
#
# Epoch 00028: val_loss improved from 5.02861 to 5.01424, saving model to Saved_Models/weights.best.from_scratch22.hdf5
# Epoch 29/1000
# 200/200 [==============================] - 188s 940ms/step - loss: 4.2925 - acc: 0.0930 - val_loss: 5.1065 - val_acc: 0.0421
#
# Epoch 00029: val_loss did not improve from 5.01424
# Epoch 30/1000
# 200/200 [==============================] - 190s 950ms/step - loss: 4.2795 - acc: 0.0948 - val_loss: 5.1097 - val_acc: 0.0321
#
# Epoch 00030: val_loss did not improve from 5.01424
# Epoch 31/1000
# 200/200 [==============================] - 190s 951ms/step - loss: 4.2214 - acc: 0.0994 - val_loss: 5.1032 - val_acc: 0.0314
#
# Epoch 00031: val_loss did not improve from 5.01424
# Epoch 32/1000
# 200/200 [==============================] - 191s 957ms/step - loss: 4.1733 - acc: 0.1109 - val_loss: 5.1123 - val_acc: 0.0405
#
# Epoch 00032: val_loss did not improve from 5.01424
# Epoch 33/1000
# 200/200 [==============================] - 191s 955ms/step - loss: 4.1641 - acc: 0.1058 - val_loss: 5.1567 - val_acc: 0.0355
#
# Epoch 00033: val_loss did not improve from 5.01424
# Epoch 34/1000
# 200/200 [==============================] - 195s 977ms/step - loss: 4.1467 - acc: 0.1069 - val_loss: 5.2384 - val_acc: 0.0289
#
# Epoch 00034: val_loss did not improve from 5.01424
# Epoch 35/1000
# 200/200 [==============================] - 191s 954ms/step - loss: 4.1267 - acc: 0.1178 - val_loss: 5.1409 - val_acc: 0.0386
#
# Epoch 00035: val_loss did not improve from 5.01424
# Epoch 36/1000
# 200/200 [==============================] - 195s 973ms/step - loss: 4.0867 - acc: 0.1148 - val_loss: 5.2655 - val_acc: 0.0305
#
# Epoch 00036: val_loss did not improve from 5.01424
# Epoch 37/1000
# 200/200 [==============================] - 191s 953ms/step - loss: 4.0829 - acc: 0.1148 - val_loss: 5.1820 - val_acc: 0.0383
#
# Epoch 00037: val_loss did not improve from 5.01424
# Epoch 38/1000
# 200/200 [==============================] - 194s 969ms/step - loss: 4.0364 - acc: 0.1264 - val_loss: 5.1223 - val_acc: 0.0403
#
# Epoch 00038: val_loss did not improve from 5.01424
# Epoch 39/1000
# 200/200 [==============================] - 196s 982ms/step - loss: 4.0333 - acc: 0.1211 - val_loss: 5.1375 - val_acc: 0.0437
#
# Epoch 00039: val_loss did not improve from 5.01424
# Epoch 40/1000
# 200/200 [==============================] - 194s 971ms/step - loss: 3.9897 - acc: 0.1297 - val_loss: 5.1207 - val_acc: 0.0500
#
# Epoch 00040: val_loss did not improve from 5.01424
# Epoch 41/1000
# 200/200 [==============================] - 193s 963ms/step - loss: 3.9677 - acc: 0.1339 - val_loss: 5.2465 - val_acc: 0.0349
#
# Epoch 00041: val_loss did not improve from 5.01424
# Epoch 42/1000
# 200/200 [==============================] - 191s 957ms/step - loss: 3.9391 - acc: 0.1352 - val_loss: 5.2616 - val_acc: 0.0321
#
# Epoch 00042: val_loss did not improve from 5.01424
# Epoch 43/1000
# 200/200 [==============================] - 193s 965ms/step - loss: 3.9038 - acc: 0.1391 - val_loss: 5.2854 - val_acc: 0.0389
#
# Epoch 00043: val_loss did not improve from 5.01424
# Epoch 44/1000
# 200/200 [==============================] - 195s 976ms/step - loss: 3.8594 - acc: 0.1523 - val_loss: 5.1817 - val_acc: 0.0447
#
# Epoch 00044: val_loss did not improve from 5.01424
# Epoch 45/1000
# 200/200 [==============================] - 191s 954ms/step - loss: 3.8680 - acc: 0.1502 - val_loss: 5.1921 - val_acc: 0.0475
#
# Epoch 00045: val_loss did not improve from 5.01424
# Epoch 46/1000
# 200/200 [==============================] - 187s 934ms/step - loss: 3.8501 - acc: 0.1489 - val_loss: 5.2362 - val_acc: 0.0434
#
# Epoch 00046: val_loss did not improve from 5.01424
# Epoch 47/1000
# 200/200 [==============================] - 189s 943ms/step - loss: 3.8336 - acc: 0.1548 - val_loss: 5.2392 - val_acc: 0.0340
#
# Epoch 00047: val_loss did not improve from 5.01424
# Epoch 48/1000
# 200/200 [==============================] - 191s 957ms/step - loss: 3.8272 - acc: 0.1542 - val_loss: 5.2740 - val_acc: 0.0453
#
# Epoch 00048: val_loss did not improve from 5.01424
# Epoch 49/1000
#  69/200 [=========>....................] - ETA: 1:17 - loss: 3.8286 - acc: 0.1590
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-45cacd20b8e6> in <module>
#      16           validation_data=test_data,
#      17           validation_steps=100,
# ---> 18           callbacks=[checkpointer])
#      19 # model.fit(train_data, test_data,
#      20 #                   callbacks = [checkpointer],
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
vals = pd.DataFrame.from_dict(Saving.history)
vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
vals.head(n=31)

# %%
import seaborn as sns
sns.set_style({'xtick.bottom':False,
               'ytick.left':False,
               'axes.spines.bottom': False,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False})

ig,(ax,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(20,20))
sns.scatterplot(x='epochs',y='acc',data=vals,ax=ax,color='r')
sns.lineplot(x='epochs',y='val_acc',data=vals,ax=ax,color='g')
sns.scatterplot(x='epochs',y='loss',data=vals,ax=ax1,color='r')
sns.lineplot(x='epochs',y='val_loss',data=vals,ax=ax1,color='g')
ax.legend(labels=['Test Accuracy','Training Accuracy'])
ax1.legend(labels=['Test Loss','Training Loss'])

# %%
# for i in range(n_iterations):
#         print('\r{}/{}'. format(i, n_iterations))
#         #initilaize random hyperparameters
#         random_parameters = {K: random.sample(V, 1)[0] for K, V in parameters_grid.items()}
#         #create model with random hyperparameters
#         model = create_model(random_parameters)
#         opt = create_RMSprop_optimizer(random_parameters)
#         #compile model
#         model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])
#         #train model
#         epochs = 40
#         checkpointer = ModelCheckpoint(filepath='saved_models/model_weights.hdf5', verbose=1, save_best_only=True)
#         early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 8)
#         history = model.fit(X_train, Y_train,
#                   callbacks = [checkpointer, early_stopping],
#                   validation_split = 0.33,
#                   epochs=epochs, batch_size = 20, verbose=1)
#         #compare current min validation loss with global min validation loss
#         current_min_val_loss = np.min(history.history['val_loss'])
#         if(current_min_val_loss < global_min_val_loss):
#             global_min_val_loss = current_min_val_loss
#             #save the best model so far
#             model.load_weights('saved_models/model_weights.hdf5')
#             model.save('saved_models/best_model.h5')
#             print('saving new best model, val_loss = {}'.format(current_min_val_loss))
#             #save best hyperparameters
#             best_hyperparameters = random_parameters
