# %% [markdown]
# # Car Make and Model Recognizer
# I shall explore here my tries to reach a good optimizer

# %% [markdown]
# ## Importing Libraries

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from glob import glob
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Pre-Processing
#
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.25,
                                   rotation_range = 90,
                                   horizontal_flip=True,
                                  validation_split = 0.3)
#test_datagen = ImageDataGenerator(rescale=1./255,
 #                                horizontal_flip = True)

train_data = train_datagen.flow_from_directory('My_Cars/trainCropped',
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='training')
test_data = train_datagen.flow_from_directory('My_Cars/trainCropped',
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                            subset='validation',
                                            shuffle=True)
# Out:
# Found 5796 images belonging to 196 classes.
# Found 2348 images belonging to 196 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(filters=64, kernel_size=4, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.0005), bias_regularizer=regularizers.l2(0.0005)))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu')) 
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv2D(filters=256, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.35))

model.add(Conv2D(filters=512, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.6))

model.add(Conv2D(filters=512, kernel_size=2, strides=1,kernel_initializer = 'random_normal',padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.9))

model.add(GlobalAveragePooling2D())
model.add(Dense(196, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      3136
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     32896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 256)       131328
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 512)       524800
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 512)       1049088
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 1,847,684
# Trainable params: 1,844,740
# Non-trainable params: 2,944
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 200

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='Saved_Models/weights.best.from_scratch28.hdf5', 
                               verbose=1, save_best_only=True)

Saving = model.fit_generator(train_data,
          steps_per_epoch=185,  
          epochs=epochs,
          verbose=1, 
          validation_data=test_data,
          validation_steps=100,
          callbacks=[checkpointer])
# model.fit(train_data, test_data,
#                   callbacks = [checkpointer],
#                   validation_split = 0.33,
#                   epochs=epochs,
#           batch_size = 20,
#           verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/200
# 185/185 [==============================] - 126s 680ms/step - loss: 5.3415 - acc: 0.0118 - val_loss: 5.3376 - val_acc: 0.0088
#
# Epoch 00001: val_loss improved from inf to 5.33764, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 2/200
# 185/185 [==============================] - 121s 652ms/step - loss: 5.2040 - acc: 0.0172 - val_loss: 5.2351 - val_acc: 0.0154
#
# Epoch 00002: val_loss improved from 5.33764 to 5.23513, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 3/200
# 185/185 [==============================] - 121s 657ms/step - loss: 5.1267 - acc: 0.0269 - val_loss: 5.4322 - val_acc: 0.0193
#
# Epoch 00003: val_loss did not improve from 5.23513
# Epoch 4/200
# 185/185 [==============================] - 128s 694ms/step - loss: 5.0771 - acc: 0.0274 - val_loss: 5.1424 - val_acc: 0.0214
#
# Epoch 00004: val_loss improved from 5.23513 to 5.14239, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 5/200
# 185/185 [==============================] - 131s 710ms/step - loss: 5.0414 - acc: 0.0306 - val_loss: 5.5310 - val_acc: 0.0148
#
# Epoch 00005: val_loss did not improve from 5.14239
# Epoch 6/200
# 185/185 [==============================] - 130s 700ms/step - loss: 4.9887 - acc: 0.0311 - val_loss: 5.0332 - val_acc: 0.0320
#
# Epoch 00006: val_loss improved from 5.14239 to 5.03325, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 7/200
# 185/185 [==============================] - 125s 677ms/step - loss: 4.9534 - acc: 0.0324 - val_loss: 5.6011 - val_acc: 0.0101
#
# Epoch 00007: val_loss did not improve from 5.03325
# Epoch 8/200
# 185/185 [==============================] - 135s 728ms/step - loss: 4.9117 - acc: 0.0432 - val_loss: 5.2336 - val_acc: 0.0204
#
# Epoch 00008: val_loss did not improve from 5.03325
# Epoch 9/200
# 185/185 [==============================] - 133s 717ms/step - loss: 4.8832 - acc: 0.0458 - val_loss: 5.0428 - val_acc: 0.0272
#
# Epoch 00009: val_loss did not improve from 5.03325
# Epoch 10/200
# 185/185 [==============================] - 131s 708ms/step - loss: 4.8484 - acc: 0.0419 - val_loss: 5.0019 - val_acc: 0.0286
#
# Epoch 00010: val_loss improved from 5.03325 to 5.00194, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 11/200
# 185/185 [==============================] - 137s 740ms/step - loss: 4.8082 - acc: 0.0529 - val_loss: 5.2201 - val_acc: 0.0274
#
# Epoch 00011: val_loss did not improve from 5.00194
# Epoch 12/200
# 185/185 [==============================] - 138s 745ms/step - loss: 4.7880 - acc: 0.0508 - val_loss: 4.9455 - val_acc: 0.0335
#
# Epoch 00012: val_loss improved from 5.00194 to 4.94554, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 13/200
# 185/185 [==============================] - 127s 684ms/step - loss: 4.7715 - acc: 0.0559 - val_loss: 5.1505 - val_acc: 0.0314
#
# Epoch 00013: val_loss did not improve from 4.94554
# Epoch 14/200
# 185/185 [==============================] - 126s 682ms/step - loss: 4.7334 - acc: 0.0591 - val_loss: 4.9788 - val_acc: 0.0346
#
# Epoch 00014: val_loss did not improve from 4.94554
# Epoch 15/200
# 185/185 [==============================] - 125s 677ms/step - loss: 4.7129 - acc: 0.0610 - val_loss: 4.9682 - val_acc: 0.0342
#
# Epoch 00015: val_loss did not improve from 4.94554
# Epoch 16/200
# 185/185 [==============================] - 122s 657ms/step - loss: 4.7020 - acc: 0.0615 - val_loss: 4.9303 - val_acc: 0.0412
#
# Epoch 00016: val_loss improved from 4.94554 to 4.93029, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 17/200
# 185/185 [==============================] - 122s 662ms/step - loss: 4.6434 - acc: 0.0716 - val_loss: 4.9910 - val_acc: 0.0349
#
# Epoch 00017: val_loss did not improve from 4.93029
# Epoch 18/200
# 185/185 [==============================] - 126s 679ms/step - loss: 4.6584 - acc: 0.0632 - val_loss: 4.8458 - val_acc: 0.0554
#
# Epoch 00018: val_loss improved from 4.93029 to 4.84575, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 19/200
# 185/185 [==============================] - 133s 717ms/step - loss: 4.6101 - acc: 0.0738 - val_loss: 4.9300 - val_acc: 0.0399
#
# Epoch 00019: val_loss did not improve from 4.84575
# Epoch 20/200
# 185/185 [==============================] - 133s 720ms/step - loss: 4.6148 - acc: 0.0686 - val_loss: 4.9598 - val_acc: 0.0351
#
# Epoch 00020: val_loss did not improve from 4.84575
# Epoch 21/200
# 185/185 [==============================] - 130s 701ms/step - loss: 4.5905 - acc: 0.0769 - val_loss: 5.1576 - val_acc: 0.0239
#
# Epoch 00021: val_loss did not improve from 4.84575
# Epoch 22/200
# 185/185 [==============================] - 134s 723ms/step - loss: 4.5541 - acc: 0.0799 - val_loss: 4.8863 - val_acc: 0.0469
#
# Epoch 00022: val_loss did not improve from 4.84575
# Epoch 23/200
# 185/185 [==============================] - 132s 715ms/step - loss: 4.5315 - acc: 0.0819 - val_loss: 4.7656 - val_acc: 0.0614
#
# Epoch 00023: val_loss improved from 4.84575 to 4.76561, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 24/200
# 185/185 [==============================] - 136s 735ms/step - loss: 4.5208 - acc: 0.0829 - val_loss: 4.9428 - val_acc: 0.0487
#
# Epoch 00024: val_loss did not improve from 4.76561
# Epoch 25/200
# 185/185 [==============================] - 127s 684ms/step - loss: 4.4982 - acc: 0.0894 - val_loss: 4.8930 - val_acc: 0.0421
#
# Epoch 00025: val_loss did not improve from 4.76561
# Epoch 26/200
# 185/185 [==============================] - 127s 686ms/step - loss: 4.4909 - acc: 0.0833 - val_loss: 4.8634 - val_acc: 0.0525
#
# Epoch 00026: val_loss did not improve from 4.76561
# Epoch 27/200
# 185/185 [==============================] - 125s 678ms/step - loss: 4.4767 - acc: 0.0872 - val_loss: 5.5068 - val_acc: 0.0283
#
# Epoch 00027: val_loss did not improve from 4.76561
# Epoch 28/200
# 185/185 [==============================] - 132s 711ms/step - loss: 4.4463 - acc: 0.0953 - val_loss: 4.9470 - val_acc: 0.0434
#
# Epoch 00028: val_loss did not improve from 4.76561
# Epoch 29/200
# 185/185 [==============================] - 130s 704ms/step - loss: 4.4445 - acc: 0.0904 - val_loss: 4.9624 - val_acc: 0.0430
#
# Epoch 00029: val_loss did not improve from 4.76561
# Epoch 30/200
# 185/185 [==============================] - 134s 722ms/step - loss: 4.4246 - acc: 0.0924 - val_loss: 4.6922 - val_acc: 0.0679
#
# Epoch 00030: val_loss improved from 4.76561 to 4.69217, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 31/200
# 185/185 [==============================] - 132s 716ms/step - loss: 4.4155 - acc: 0.0971 - val_loss: 5.0062 - val_acc: 0.0381
#
# Epoch 00031: val_loss did not improve from 4.69217
# Epoch 32/200
# 185/185 [==============================] - 132s 715ms/step - loss: 4.3711 - acc: 0.1012 - val_loss: 5.0214 - val_acc: 0.0446
#
# Epoch 00032: val_loss did not improve from 4.69217
# Epoch 33/200
# 185/185 [==============================] - 132s 716ms/step - loss: 4.3384 - acc: 0.1078 - val_loss: 4.8003 - val_acc: 0.0582
#
# Epoch 00033: val_loss did not improve from 4.69217
# Epoch 34/200
# 185/185 [==============================] - 134s 722ms/step - loss: 4.3433 - acc: 0.1044 - val_loss: 4.8935 - val_acc: 0.0478
#
# Epoch 00034: val_loss did not improve from 4.69217
# Epoch 35/200
# 185/185 [==============================] - 132s 714ms/step - loss: 4.3168 - acc: 0.1100 - val_loss: 5.2601 - val_acc: 0.0313
#
# Epoch 00035: val_loss did not improve from 4.69217
# Epoch 36/200
# 185/185 [==============================] - 132s 714ms/step - loss: 4.3047 - acc: 0.1111 - val_loss: 4.7578 - val_acc: 0.0544
#
# Epoch 00036: val_loss did not improve from 4.69217
# Epoch 37/200
# 185/185 [==============================] - 123s 664ms/step - loss: 4.2800 - acc: 0.1105 - val_loss: 4.7261 - val_acc: 0.0560
#
# Epoch 00037: val_loss did not improve from 4.69217
# Epoch 38/200
# 185/185 [==============================] - 122s 661ms/step - loss: 4.2732 - acc: 0.1105 - val_loss: 4.7431 - val_acc: 0.0597
#
# Epoch 00038: val_loss did not improve from 4.69217
# Epoch 39/200
# 185/185 [==============================] - 126s 680ms/step - loss: 4.2383 - acc: 0.1233 - val_loss: 4.6908 - val_acc: 0.0667
#
# Epoch 00039: val_loss improved from 4.69217 to 4.69078, saving model to Saved_Models/weights.best.from_scratch28.hdf5
# Epoch 40/200
#  27/185 [===>..........................] - ETA: 1:01 - loss: 4.2799 - acc: 0.1065
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-5-c0dbcf3ebebf> in <module>
#      16           validation_data=test_data,
#      17           validation_steps=100,
# ---> 18           callbacks=[checkpointer])
#      19 # model.fit(train_data, test_data,
#      20 #                   callbacks = [checkpointer],
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# InternalError: GPU sync failed

# %%
vals = pd.DataFrame.from_dict(Saving.history)
vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
vals.head(n=31)

# %%
import seaborn as sns
sns.set_style({'xtick.bottom':False,
               'ytick.left':False,
               'axes.spines.bottom': False,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False})

ig,(ax,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(20,20))
sns.scatterplot(x='epochs',y='acc',data=vals,ax=ax,color='r')
sns.lineplot(x='epochs',y='val_acc',data=vals,ax=ax,color='g')
sns.scatterplot(x='epochs',y='loss',data=vals,ax=ax1,color='r')
sns.lineplot(x='epochs',y='val_loss',data=vals,ax=ax1,color='g')
ax.legend(labels=['Test Accuracy','Training Accuracy'])
ax1.legend(labels=['Test Loss','Training Loss'])

# %%
# for i in range(n_iterations):
#         print('\r{}/{}'. format(i, n_iterations))
#         #initilaize random hyperparameters
#         random_parameters = {K: random.sample(V, 1)[0] for K, V in parameters_grid.items()}
#         #create model with random hyperparameters
#         model = create_model(random_parameters)
#         opt = create_RMSprop_optimizer(random_parameters)
#         #compile model
#         model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])
#         #train model
#         epochs = 40
#         checkpointer = ModelCheckpoint(filepath='saved_models/model_weights.hdf5', verbose=1, save_best_only=True)
#         early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 8)
#         history = model.fit(X_train, Y_train,
#                   callbacks = [checkpointer, early_stopping],
#                   validation_split = 0.33,
#                   epochs=epochs, batch_size = 20, verbose=1)
#         #compare current min validation loss with global min validation loss
#         current_min_val_loss = np.min(history.history['val_loss'])
#         if(current_min_val_loss < global_min_val_loss):
#             global_min_val_loss = current_min_val_loss
#             #save the best model so far
#             model.load_weights('saved_models/model_weights.hdf5')
#             model.save('saved_models/best_model.h5')
#             print('saving new best model, val_loss = {}'.format(current_min_val_loss))
#             #save best hyperparameters
#             best_hyperparameters = random_parameters
