# %% [markdown]
# # Car Make and Model Recognizer
# I shall explore here my tries to reach a good optimizer

# %% [markdown]
# ## Importing Libraries

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from glob import glob
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Pre-Processing
#
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.25,
                                   rotation_range = 90,
                                   horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255,
                                 horizontal_flip = True)

train_data = train_datagen.flow_from_directory('My_Cars/train',
                                              target_size=(256,256),
                                              batch_size=32,
                                              class_mode='categorical')
test_data = test_datagen.flow_from_directory('My_Cars/test',
                                              target_size=(256,256),
                                              batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 8144 images belonging to 196 classes.
# Found 8041 images belonging to 196 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()

#First Layer
model.add(Conv2D(filters=32, kernel_size=6,padding='same', input_shape=(256, 256, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(BatchNormalization())
#model.add(Dropout(0.25))
#Second Layer
model.add(Conv2D(filters=64, kernel_size=6, activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(BatchNormalization())
#model.add(Dropout(0.25))
#Third Layer
model.add(Conv2D(filters=128, kernel_size=6, activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
#model.add(Dropout(0.25))
model.add(BatchNormalization())
#Fourth Layer
model.add(Conv2D(filters=128, kernel_size=6,padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(Dropout(0.25))


#Last Layer
#model.add(Flatten())

model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(196, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      3488
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 59, 59, 64)        73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       295040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 128)         589952
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1, 512)         66048
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 1, 512)         262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 1,396,516
# Trainable params: 1,394,020
# Non-trainable params: 2,496
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 1000

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='Saved_Models/weights.best.from_scratch21.hdf5', 
                               verbose=1, save_best_only=True)

Saving = model.fit_generator(train_data,
          steps_per_epoch=256,  
          epochs=epochs,
          verbose=1, 
          validation_data=test_data,
          validation_steps=251,
          callbacks=[checkpointer])
# model.fit(train_data, test_data,
#                   callbacks = [checkpointer],
#                   validation_split = 0.33,
#                   epochs=epochs,
#           batch_size = 20,
#           verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1000
# 256/256 [==============================] - 283s 1s/step - loss: 5.5937 - acc: 0.0100 - val_loss: 14.9337 - val_acc: 0.0049
#
# Epoch 00001: val_loss improved from inf to 14.93375, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 2/1000
# 256/256 [==============================] - 237s 926ms/step - loss: 5.3586 - acc: 0.0150 - val_loss: 5.7263 - val_acc: 0.0117
#
# Epoch 00002: val_loss improved from 14.93375 to 5.72629, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 3/1000
# 256/256 [==============================] - 246s 959ms/step - loss: 5.2555 - acc: 0.0181 - val_loss: 6.6389 - val_acc: 0.0110
#
# Epoch 00003: val_loss did not improve from 5.72629
# Epoch 4/1000
# 256/256 [==============================] - 244s 952ms/step - loss: 5.1806 - acc: 0.0208 - val_loss: 5.3324 - val_acc: 0.0167
#
# Epoch 00004: val_loss improved from 5.72629 to 5.33237, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 5/1000
# 256/256 [==============================] - 243s 950ms/step - loss: 5.1279 - acc: 0.0195 - val_loss: 5.5275 - val_acc: 0.0164
#
# Epoch 00005: val_loss did not improve from 5.33237
# Epoch 6/1000
# 256/256 [==============================] - 251s 981ms/step - loss: 5.0592 - acc: 0.0244 - val_loss: 5.1524 - val_acc: 0.0223
#
# Epoch 00006: val_loss improved from 5.33237 to 5.15239, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 7/1000
# 256/256 [==============================] - 258s 1s/step - loss: 4.9939 - acc: 0.0293 - val_loss: 5.1674 - val_acc: 0.0272
#
# Epoch 00007: val_loss did not improve from 5.15239
# Epoch 8/1000
# 256/256 [==============================] - 262s 1s/step - loss: 4.9458 - acc: 0.0337 - val_loss: 5.0178 - val_acc: 0.0348
#
# Epoch 00008: val_loss improved from 5.15239 to 5.01781, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 9/1000
# 256/256 [==============================] - 270s 1s/step - loss: 4.9060 - acc: 0.0365 - val_loss: 5.0947 - val_acc: 0.0340
#
# Epoch 00009: val_loss did not improve from 5.01781
# Epoch 10/1000
# 256/256 [==============================] - 262s 1s/step - loss: 4.8555 - acc: 0.0437 - val_loss: 5.1332 - val_acc: 0.0303
#
# Epoch 00010: val_loss did not improve from 5.01781
# Epoch 11/1000
# 256/256 [==============================] - 265s 1s/step - loss: 4.8098 - acc: 0.0475 - val_loss: 5.0400 - val_acc: 0.0321
#
# Epoch 00011: val_loss did not improve from 5.01781
# Epoch 12/1000
# 256/256 [==============================] - 247s 965ms/step - loss: 4.7584 - acc: 0.0548 - val_loss: 4.9421 - val_acc: 0.0426
#
# Epoch 00012: val_loss improved from 5.01781 to 4.94213, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 13/1000
# 256/256 [==============================] - 233s 911ms/step - loss: 4.7162 - acc: 0.0582 - val_loss: 5.0031 - val_acc: 0.0391
#
# Epoch 00013: val_loss did not improve from 4.94213
# Epoch 14/1000
# 256/256 [==============================] - 232s 907ms/step - loss: 4.6769 - acc: 0.0569 - val_loss: 4.8637 - val_acc: 0.0528
#
# Epoch 00014: val_loss improved from 4.94213 to 4.86370, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 15/1000
# 256/256 [==============================] - 234s 915ms/step - loss: 4.6377 - acc: 0.0637 - val_loss: 4.9124 - val_acc: 0.0458
#
# Epoch 00015: val_loss did not improve from 4.86370
# Epoch 16/1000
# 256/256 [==============================] - 234s 912ms/step - loss: 4.6167 - acc: 0.0638 - val_loss: 4.9000 - val_acc: 0.0483
#
# Epoch 00016: val_loss did not improve from 4.86370
# Epoch 17/1000
# 256/256 [==============================] - 238s 928ms/step - loss: 4.5778 - acc: 0.0685 - val_loss: 4.9453 - val_acc: 0.0481
#
# Epoch 00017: val_loss did not improve from 4.86370
# Epoch 18/1000
# 256/256 [==============================] - 232s 908ms/step - loss: 4.5110 - acc: 0.0730 - val_loss: 4.8259 - val_acc: 0.0537
#
# Epoch 00018: val_loss improved from 4.86370 to 4.82592, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 19/1000
# 256/256 [==============================] - 234s 912ms/step - loss: 4.5068 - acc: 0.0747 - val_loss: 4.8739 - val_acc: 0.0483
#
# Epoch 00019: val_loss did not improve from 4.82592
# Epoch 20/1000
# 256/256 [==============================] - 232s 905ms/step - loss: 4.4482 - acc: 0.0798 - val_loss: 4.8901 - val_acc: 0.0523
#
# Epoch 00020: val_loss did not improve from 4.82592
# Epoch 21/1000
# 256/256 [==============================] - 231s 904ms/step - loss: 4.4143 - acc: 0.0828 - val_loss: 5.3700 - val_acc: 0.0386
#
# Epoch 00021: val_loss did not improve from 4.82592
# Epoch 22/1000
# 256/256 [==============================] - 234s 914ms/step - loss: 4.4017 - acc: 0.0878 - val_loss: 4.9622 - val_acc: 0.0462
#
# Epoch 00022: val_loss did not improve from 4.82592
# Epoch 23/1000
# 256/256 [==============================] - 236s 922ms/step - loss: 4.3641 - acc: 0.0884 - val_loss: 4.7243 - val_acc: 0.0670
#
# Epoch 00023: val_loss improved from 4.82592 to 4.72428, saving model to Saved_Models/weights.best.from_scratch21.hdf5
# Epoch 24/1000
# 256/256 [==============================] - 234s 912ms/step - loss: 4.3280 - acc: 0.0948 - val_loss: 5.0061 - val_acc: 0.0466
#
# Epoch 00024: val_loss did not improve from 4.72428
# Epoch 25/1000
# 256/256 [==============================] - 233s 910ms/step - loss: 4.2924 - acc: 0.1000 - val_loss: 4.8962 - val_acc: 0.0553
#
# Epoch 00025: val_loss did not improve from 4.72428
# Epoch 26/1000
# 256/256 [==============================] - 230s 900ms/step - loss: 4.2460 - acc: 0.1042 - val_loss: 4.8023 - val_acc: 0.0667
#
# Epoch 00026: val_loss did not improve from 4.72428
# Epoch 27/1000
# 256/256 [==============================] - 233s 911ms/step - loss: 4.2251 - acc: 0.1033 - val_loss: 4.8314 - val_acc: 0.0647
#
# Epoch 00027: val_loss did not improve from 4.72428
# Epoch 28/1000
# 256/256 [==============================] - 233s 909ms/step - loss: 4.2125 - acc: 0.1057 - val_loss: 4.9559 - val_acc: 0.0519
#
# Epoch 00028: val_loss did not improve from 4.72428
# Epoch 29/1000
# 256/256 [==============================] - 234s 913ms/step - loss: 4.1876 - acc: 0.1101 - val_loss: 4.8088 - val_acc: 0.0597
#
# Epoch 00029: val_loss did not improve from 4.72428
# Epoch 30/1000
# 256/256 [==============================] - 233s 911ms/step - loss: 4.1388 - acc: 0.1180 - val_loss: 4.8587 - val_acc: 0.0634
#
# Epoch 00030: val_loss did not improve from 4.72428
# Epoch 31/1000
# 256/256 [==============================] - 230s 897ms/step - loss: 4.1212 - acc: 0.1272 - val_loss: 4.9872 - val_acc: 0.0533
#
# Epoch 00031: val_loss did not improve from 4.72428
# Epoch 32/1000
# 256/256 [==============================] - 240s 937ms/step - loss: 4.0909 - acc: 0.1285 - val_loss: 4.9135 - val_acc: 0.0680
#
# Epoch 00032: val_loss did not improve from 4.72428
# Epoch 33/1000
# 256/256 [==============================] - 241s 943ms/step - loss: 4.0682 - acc: 0.1239 - val_loss: 4.8051 - val_acc: 0.0739
#
# Epoch 00033: val_loss did not improve from 4.72428
# Epoch 34/1000
# 256/256 [==============================] - 233s 912ms/step - loss: 4.0242 - acc: 0.1355 - val_loss: 5.0985 - val_acc: 0.0607
#
# Epoch 00034: val_loss did not improve from 4.72428
# Epoch 35/1000
# 256/256 [==============================] - 233s 910ms/step - loss: 4.0158 - acc: 0.1304 - val_loss: 4.9267 - val_acc: 0.0599
#
# Epoch 00035: val_loss did not improve from 4.72428
# Epoch 36/1000
# 256/256 [==============================] - 236s 922ms/step - loss: 3.9964 - acc: 0.1362 - val_loss: 5.0718 - val_acc: 0.0564
#
# Epoch 00036: val_loss did not improve from 4.72428
# Epoch 37/1000
# 256/256 [==============================] - 234s 914ms/step - loss: 3.9745 - acc: 0.1382 - val_loss: 5.1506 - val_acc: 0.0557
#
# Epoch 00037: val_loss did not improve from 4.72428
# Epoch 38/1000
# 256/256 [==============================] - 235s 918ms/step - loss: 3.9507 - acc: 0.1400 - val_loss: 4.9963 - val_acc: 0.0606
#
# Epoch 00038: val_loss did not improve from 4.72428
# Epoch 39/1000
# 256/256 [==============================] - 231s 903ms/step - loss: 3.9433 - acc: 0.1400 - val_loss: 4.8092 - val_acc: 0.0763
# Epoch 00039: val_loss did not improve from 4.72428
# Epoch 40/1000
# 256/256 [==============================] - 234s 914ms/step - loss: 3.8922 - acc: 0.1511 - val_loss: 4.9665 - val_acc: 0.0593
#
# Epoch 00040: val_loss did not improve from 4.72428
# Epoch 41/1000
#  67/256 [======>.......................] - ETA: 1:49 - loss: 3.8043 - acc: 0.1511
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e6ccc9a5804d> in <module>
#      16           validation_data=test_data,
#      17           validation_steps=251,
# ---> 18           callbacks=[checkpointer])
#      19 # model.fit(train_data, test_data,
#      20 #                   callbacks = [checkpointer],
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
vals = pd.DataFrame.from_dict(Saving.history)
vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
vals.head(n=31)

# %%
import seaborn as sns
sns.set_style({'xtick.bottom':False,
               'ytick.left':False,
               'axes.spines.bottom': False,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False})

ig,(ax,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(20,20))
sns.scatterplot(x='epochs',y='acc',data=vals,ax=ax,color='r')
sns.lineplot(x='epochs',y='val_acc',data=vals,ax=ax,color='g')
sns.scatterplot(x='epochs',y='loss',data=vals,ax=ax1,color='r')
sns.lineplot(x='epochs',y='val_loss',data=vals,ax=ax1,color='g')
ax.legend(labels=['Test Accuracy','Training Accuracy'])
ax1.legend(labels=['Test Loss','Training Loss'])

# %%
# for i in range(n_iterations):
#         print('\r{}/{}'. format(i, n_iterations))
#         #initilaize random hyperparameters
#         random_parameters = {K: random.sample(V, 1)[0] for K, V in parameters_grid.items()}
#         #create model with random hyperparameters
#         model = create_model(random_parameters)
#         opt = create_RMSprop_optimizer(random_parameters)
#         #compile model
#         model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])
#         #train model
#         epochs = 40
#         checkpointer = ModelCheckpoint(filepath='saved_models/model_weights.hdf5', verbose=1, save_best_only=True)
#         early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 8)
#         history = model.fit(X_train, Y_train,
#                   callbacks = [checkpointer, early_stopping],
#                   validation_split = 0.33,
#                   epochs=epochs, batch_size = 20, verbose=1)
#         #compare current min validation loss with global min validation loss
#         current_min_val_loss = np.min(history.history['val_loss'])
#         if(current_min_val_loss < global_min_val_loss):
#             global_min_val_loss = current_min_val_loss
#             #save the best model so far
#             model.load_weights('saved_models/model_weights.hdf5')
#             model.save('saved_models/best_model.h5')
#             print('saving new best model, val_loss = {}'.format(current_min_val_loss))
#             #save best hyperparameters
#             best_hyperparameters = random_parameters
