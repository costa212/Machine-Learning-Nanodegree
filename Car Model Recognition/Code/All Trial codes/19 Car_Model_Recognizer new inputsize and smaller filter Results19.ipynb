# %% [markdown]
# # Car Make and Model Recognizer
# I shall explore here my tries to reach a good optimizer

# %% [markdown]
# ## Importing Libraries

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from glob import glob
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Pre-Processing
#
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.25,
                                   rotation_range = 90,
                                   horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255,
                                 horizontal_flip = True)

train_data = train_datagen.flow_from_directory('My_Cars/train',
                                              target_size=(256,256),
                                              batch_size=32,
                                              class_mode='categorical')
test_data = test_datagen.flow_from_directory('My_Cars/test',
                                              target_size=(256,256),
                                              batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 8144 images belonging to 196 classes.
# Found 8041 images belonging to 196 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()

#First Layer
model.add(Conv2D(filters=32, kernel_size=6,padding='same', input_shape=(256, 256, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(BatchNormalization())
#model.add(Dropout(0.25))
#Second Layer
model.add(Conv2D(filters=64, kernel_size=6, activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(BatchNormalization())
#model.add(Dropout(0.25))
#Third Layer
model.add(Conv2D(filters=128, kernel_size=6, activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
#model.add(Dropout(0.25))
model.add(BatchNormalization())
#Fourth Layer
model.add(Conv2D(filters=128, kernel_size=6,padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2,strides = 4))
model.add(Dropout(0.25))

#model.add(GlobalAveragePooling2D())
#Last Layer
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())

model.add(Dense(196, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      3488
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 59, 59, 64)        73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       295040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 128)         589952
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               66048
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 1,396,516
# Trainable params: 1,394,020
# Non-trainable params: 2,496
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 1000

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='Saved_Models/weights.best.from_scratch18.hdf5', 
                               verbose=1, save_best_only=True)

Saving = model.fit_generator(train_data,
          steps_per_epoch=100,  
          epochs=epochs,
          verbose=1, 
          validation_data=test_data,
          validation_steps=251,
          callbacks=[checkpointer])
# model.fit(train_data, test_data,
#                   callbacks = [checkpointer],
#                   validation_split = 0.33,
#                   epochs=epochs,
#           batch_size = 20,
#           verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\CostaPC2\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1000
# 100/100 [==============================] - 139s 1s/step - loss: 5.7676 - acc: 0.0100 - val_loss: 13.5788 - val_acc: 0.0055
#
# Epoch 00001: val_loss improved from inf to 13.57882, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 2/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.5879 - acc: 0.0078 - val_loss: 8.2020 - val_acc: 0.0067
#
# Epoch 00002: val_loss improved from 13.57882 to 8.20200, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 3/1000
# 100/100 [==============================] - 129s 1s/step - loss: 5.4383 - acc: 0.0119 - val_loss: 6.2018 - val_acc: 0.0070
#
# Epoch 00003: val_loss improved from 8.20200 to 6.20177, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 4/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.3694 - acc: 0.0141 - val_loss: 5.8210 - val_acc: 0.0129
#
# Epoch 00004: val_loss improved from 6.20177 to 5.82102, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 5/1000
# 100/100 [==============================] - 131s 1s/step - loss: 5.3496 - acc: 0.0147 - val_loss: 5.8261 - val_acc: 0.0124
#
# Epoch 00005: val_loss did not improve from 5.82102
# Epoch 6/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.2504 - acc: 0.0200 - val_loss: 5.4574 - val_acc: 0.0144
#
# Epoch 00006: val_loss improved from 5.82102 to 5.45736, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 7/1000
# 100/100 [==============================] - 131s 1s/step - loss: 5.2532 - acc: 0.0169 - val_loss: 5.6709 - val_acc: 0.0106
#
# Epoch 00007: val_loss did not improve from 5.45736
# Epoch 8/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.2115 - acc: 0.0191 - val_loss: 5.6823 - val_acc: 0.0080
#
# Epoch 00008: val_loss did not improve from 5.45736
# Epoch 9/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.2177 - acc: 0.0156 - val_loss: 5.1819 - val_acc: 0.0197
#
# Epoch 00009: val_loss improved from 5.45736 to 5.18186, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 10/1000
# 100/100 [==============================] - 131s 1s/step - loss: 5.1846 - acc: 0.0219 - val_loss: 5.2136 - val_acc: 0.0195
#
# Epoch 00010: val_loss did not improve from 5.18186
# Epoch 11/1000
# 100/100 [==============================] - 129s 1s/step - loss: 5.1303 - acc: 0.0175 - val_loss: 5.1151 - val_acc: 0.0232
#
# Epoch 00011: val_loss improved from 5.18186 to 5.11515, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 12/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.1241 - acc: 0.0194 - val_loss: 5.3833 - val_acc: 0.0190
#
# Epoch 00012: val_loss did not improve from 5.11515
# Epoch 13/1000
# 100/100 [==============================] - 129s 1s/step - loss: 5.1190 - acc: 0.0228 - val_loss: 5.1638 - val_acc: 0.0204
#
# Epoch 00013: val_loss did not improve from 5.11515
# Epoch 14/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.0929 - acc: 0.0247 - val_loss: 5.2203 - val_acc: 0.0237
#
# Epoch 00014: val_loss did not improve from 5.11515
# Epoch 15/1000
# 100/100 [==============================] - 130s 1s/step - loss: 5.0834 - acc: 0.0225 - val_loss: 5.2017 - val_acc: 0.0202
#
# Epoch 00015: val_loss did not improve from 5.11515
# Epoch 16/1000
# 100/100 [==============================] - 129s 1s/step - loss: 5.0356 - acc: 0.0297 - val_loss: 5.2206 - val_acc: 0.0225
#
# Epoch 00016: val_loss did not improve from 5.11515
# Epoch 17/1000
# 100/100 [==============================] - 129s 1s/step - loss: 5.0457 - acc: 0.0244 - val_loss: 5.1158 - val_acc: 0.0341
#
# Epoch 00017: val_loss did not improve from 5.11515
# Epoch 18/1000
# 100/100 [==============================] - 128s 1s/step - loss: 5.0398 - acc: 0.0291 - val_loss: 5.1889 - val_acc: 0.0263
#
# Epoch 00018: val_loss did not improve from 5.11515
# Epoch 19/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.9816 - acc: 0.0356 - val_loss: 5.1516 - val_acc: 0.0214
#
# Epoch 00019: val_loss did not improve from 5.11515
# Epoch 20/1000
# 100/100 [==============================] - 131s 1s/step - loss: 5.0232 - acc: 0.0331 - val_loss: 5.2070 - val_acc: 0.0221
#
# Epoch 00020: val_loss did not improve from 5.11515
# Epoch 21/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.9187 - acc: 0.0375 - val_loss: 5.0941 - val_acc: 0.0316
#
# Epoch 00021: val_loss improved from 5.11515 to 5.09410, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 22/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.9564 - acc: 0.0312 - val_loss: 5.2676 - val_acc: 0.0233
#
# Epoch 00022: val_loss did not improve from 5.09410
# Epoch 23/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.9246 - acc: 0.0416 - val_loss: 5.2065 - val_acc: 0.0219
#
# Epoch 00023: val_loss did not improve from 5.09410
# Epoch 24/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.8671 - acc: 0.0416 - val_loss: 5.1943 - val_acc: 0.0247
#
# Epoch 00024: val_loss did not improve from 5.09410
# Epoch 25/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.9016 - acc: 0.0450 - val_loss: 5.2606 - val_acc: 0.0261
#
# Epoch 00025: val_loss did not improve from 5.09410
# Epoch 26/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.8399 - acc: 0.0437 - val_loss: 5.0282 - val_acc: 0.0366
#
# Epoch 00026: val_loss improved from 5.09410 to 5.02825, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 27/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.8703 - acc: 0.0362 - val_loss: 5.0822 - val_acc: 0.0347
#
# Epoch 00027: val_loss did not improve from 5.02825
# Epoch 28/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.8770 - acc: 0.0434 - val_loss: 5.2484 - val_acc: 0.0233
#
# Epoch 00028: val_loss did not improve from 5.02825
# Epoch 29/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.7903 - acc: 0.0456 - val_loss: 5.0391 - val_acc: 0.0377
#
# Epoch 00029: val_loss did not improve from 5.02825
# Epoch 30/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.8250 - acc: 0.0462 - val_loss: 4.9970 - val_acc: 0.0335
#
# Epoch 00030: val_loss improved from 5.02825 to 4.99702, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 31/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.7449 - acc: 0.0541 - val_loss: 5.2157 - val_acc: 0.0253
#
# Epoch 00031: val_loss did not improve from 4.99702
# Epoch 32/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.7798 - acc: 0.0447 - val_loss: 5.0434 - val_acc: 0.0385
#
# Epoch 00032: val_loss did not improve from 4.99702
# Epoch 33/1000
# 100/100 [==============================] - 136s 1s/step - loss: 4.8051 - acc: 0.0531 - val_loss: 5.0115 - val_acc: 0.0398
#
# Epoch 00033: val_loss did not improve from 4.99702
# Epoch 34/1000
# 100/100 [==============================] - 138s 1s/step - loss: 4.6888 - acc: 0.0587 - val_loss: 4.9735 - val_acc: 0.0401
#
# Epoch 00034: val_loss improved from 4.99702 to 4.97345, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 35/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.7192 - acc: 0.0584 - val_loss: 4.8894 - val_acc: 0.0519
#
# Epoch 00035: val_loss improved from 4.97345 to 4.88940, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 36/1000
# 100/100 [==============================] - 128s 1s/step - loss: 4.7323 - acc: 0.0519 - val_loss: 5.1466 - val_acc: 0.0262
#
# Epoch 00036: val_loss did not improve from 4.88940
# Epoch 37/1000
# 100/100 [==============================] - 128s 1s/step - loss: 4.6935 - acc: 0.0581 - val_loss: 5.2045 - val_acc: 0.0317
#
# Epoch 00037: val_loss did not improve from 4.88940
# Epoch 38/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.7210 - acc: 0.0512 - val_loss: 4.9150 - val_acc: 0.0463
#
# Epoch 00038: val_loss did not improve from 4.88940
# Epoch 39/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.6185 - acc: 0.0591 - val_loss: 4.9659 - val_acc: 0.0412
#
# Epoch 00039: val_loss did not improve from 4.88940
# Epoch 40/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.6684 - acc: 0.0578 - val_loss: 5.1381 - val_acc: 0.0285
#
# Epoch 00040: val_loss did not improve from 4.88940
# Epoch 41/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.6237 - acc: 0.0578 - val_loss: 4.9221 - val_acc: 0.0492
#
# Epoch 00041: val_loss did not improve from 4.88940
# Epoch 42/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.5753 - acc: 0.0656 - val_loss: 4.9897 - val_acc: 0.0423
#
# Epoch 00042: val_loss did not improve from 4.88940
# Epoch 43/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.6461 - acc: 0.0609 - val_loss: 5.0305 - val_acc: 0.0381
#
# Epoch 00043: val_loss did not improve from 4.88940
# Epoch 44/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.5821 - acc: 0.0703 - val_loss: 4.8728 - val_acc: 0.0549
#
# Epoch 00044: val_loss improved from 4.88940 to 4.87283, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 45/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.5821 - acc: 0.0616 - val_loss: 4.8635 - val_acc: 0.0506
#
# Epoch 00045: val_loss improved from 4.87283 to 4.86351, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 46/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.5768 - acc: 0.0691 - val_loss: 4.9333 - val_acc: 0.0472
#
# Epoch 00046: val_loss did not improve from 4.86351
# Epoch 47/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.4839 - acc: 0.0778 - val_loss: 4.9773 - val_acc: 0.0519
#
# Epoch 00047: val_loss did not improve from 4.86351
# Epoch 48/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.5619 - acc: 0.0706 - val_loss: 5.1867 - val_acc: 0.0316
#
# Epoch 00048: val_loss did not improve from 4.86351
# Epoch 49/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.5150 - acc: 0.0700 - val_loss: 4.8279 - val_acc: 0.0578
#
# Epoch 00049: val_loss improved from 4.86351 to 4.82787, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 50/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.5068 - acc: 0.0722 - val_loss: 4.8939 - val_acc: 0.0543
#
# Epoch 00050: val_loss did not improve from 4.82787
# Epoch 51/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.5615 - acc: 0.0750 - val_loss: 5.0548 - val_acc: 0.0380
#
# Epoch 00051: val_loss did not improve from 4.82787
# Epoch 52/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.4290 - acc: 0.0853 - val_loss: 4.9905 - val_acc: 0.0499
#
# Epoch 00052: val_loss did not improve from 4.82787
# Epoch 53/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.4846 - acc: 0.0791 - val_loss: 4.8909 - val_acc: 0.0577
#
# Epoch 00053: val_loss did not improve from 4.82787
# Epoch 54/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.4371 - acc: 0.0869 - val_loss: 5.0569 - val_acc: 0.0377
#
# Epoch 00054: val_loss did not improve from 4.82787
# Epoch 55/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.4185 - acc: 0.0913 - val_loss: 4.9435 - val_acc: 0.0529
#
# Epoch 00055: val_loss did not improve from 4.82787
# Epoch 56/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.5111 - acc: 0.0719 - val_loss: 4.9257 - val_acc: 0.0528
#
# Epoch 00056: val_loss did not improve from 4.82787
# Epoch 57/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.3048 - acc: 0.1069 - val_loss: 5.0252 - val_acc: 0.0501
#
# Epoch 00057: val_loss did not improve from 4.82787
# Epoch 58/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.4478 - acc: 0.0813 - val_loss: 4.8958 - val_acc: 0.0624
#
# Epoch 00058: val_loss did not improve from 4.82787
# Epoch 59/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.3965 - acc: 0.0934 - val_loss: 5.0420 - val_acc: 0.0443
#
# Epoch 00059: val_loss did not improve from 4.82787
# Epoch 60/1000
# 100/100 [==============================] - 128s 1s/step - loss: 4.3598 - acc: 0.0891 - val_loss: 4.9423 - val_acc: 0.0463
#
# Epoch 00060: val_loss did not improve from 4.82787
# Epoch 61/1000
# 100/100 [==============================] - 132s 1s/step - loss: 4.4382 - acc: 0.0828 - val_loss: 5.0002 - val_acc: 0.0448
#
# Epoch 00061: val_loss did not improve from 4.82787
# Epoch 62/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.2725 - acc: 0.1000 - val_loss: 4.9790 - val_acc: 0.0547
#
# Epoch 00062: val_loss did not improve from 4.82787
# Epoch 63/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.3598 - acc: 0.0900 - val_loss: 5.0430 - val_acc: 0.0451
#
# Epoch 00063: val_loss did not improve from 4.82787
# Epoch 64/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.3376 - acc: 0.0984 - val_loss: 4.8377 - val_acc: 0.0588
#
# Epoch 00064: val_loss did not improve from 4.82787
# Epoch 65/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.3120 - acc: 0.0950 - val_loss: 4.7839 - val_acc: 0.0648
#
# Epoch 00065: val_loss improved from 4.82787 to 4.78391, saving model to Saved_Models/weights.best.from_scratch18.hdf5
# Epoch 66/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.3254 - acc: 0.1013 - val_loss: 4.9122 - val_acc: 0.0563
#
# Epoch 00066: val_loss did not improve from 4.78391
# Epoch 67/1000
# 100/100 [==============================] - 128s 1s/step - loss: 4.1912 - acc: 0.1106 - val_loss: 5.4263 - val_acc: 0.0311
#
# Epoch 00067: val_loss did not improve from 4.78391
# Epoch 68/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.2956 - acc: 0.1025 - val_loss: 5.0782 - val_acc: 0.0483
#
# Epoch 00068: val_loss did not improve from 4.78391
# Epoch 69/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.3007 - acc: 0.1009 - val_loss: 4.9073 - val_acc: 0.0531
#
# Epoch 00069: val_loss did not improve from 4.78391
# Epoch 70/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.2222 - acc: 0.1031 - val_loss: 5.0968 - val_acc: 0.0482
#
# Epoch 00070: val_loss did not improve from 4.78391
# Epoch 71/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.2863 - acc: 0.1047 - val_loss: 4.8597 - val_acc: 0.0604
#
# Epoch 00071: val_loss did not improve from 4.78391
# Epoch 72/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.2011 - acc: 0.1072 - val_loss: 5.0157 - val_acc: 0.0498
#
# Epoch 00072: val_loss did not improve from 4.78391
# Epoch 73/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.2482 - acc: 0.0969 - val_loss: 4.9929 - val_acc: 0.0556
#
# Epoch 00073: val_loss did not improve from 4.78391
# Epoch 74/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.3025 - acc: 0.0997 - val_loss: 4.8342 - val_acc: 0.0663
#
# Epoch 00074: val_loss did not improve from 4.78391
# Epoch 75/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.1704 - acc: 0.1184 - val_loss: 4.8368 - val_acc: 0.0637
#
# Epoch 00075: val_loss did not improve from 4.78391
# Epoch 76/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.2328 - acc: 0.1037 - val_loss: 5.1778 - val_acc: 0.0463
#
# Epoch 00076: val_loss did not improve from 4.78391
# Epoch 77/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.1518 - acc: 0.1144 - val_loss: 5.4337 - val_acc: 0.0348
#
# Epoch 00077: val_loss did not improve from 4.78391
# Epoch 78/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.1834 - acc: 0.1147 - val_loss: 4.9210 - val_acc: 0.0449
#
# Epoch 00078: val_loss did not improve from 4.78391
# Epoch 79/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.2322 - acc: 0.1019 - val_loss: 4.8711 - val_acc: 0.0673
#
# Epoch 00079: val_loss did not improve from 4.78391
# Epoch 80/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.0878 - acc: 0.1253 - val_loss: 4.9506 - val_acc: 0.0503
#
# Epoch 00080: val_loss did not improve from 4.78391
# Epoch 81/1000
# 100/100 [==============================] - 127s 1s/step - loss: 4.2255 - acc: 0.1066 - val_loss: 4.7925 - val_acc: 0.0654
#
# Epoch 00081: val_loss did not improve from 4.78391
# Epoch 82/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.1151 - acc: 0.1288 - val_loss: 4.9797 - val_acc: 0.0579
#
# Epoch 00082: val_loss did not improve from 4.78391
# Epoch 83/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.1038 - acc: 0.1153 - val_loss: 4.8296 - val_acc: 0.0683
#
# Epoch 00083: val_loss did not improve from 4.78391
# Epoch 84/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.1563 - acc: 0.1163 - val_loss: 5.0876 - val_acc: 0.0489
#
# Epoch 00084: val_loss did not improve from 4.78391
# Epoch 85/1000
# 100/100 [==============================] - 127s 1s/step - loss: 4.1242 - acc: 0.1175 - val_loss: 4.7957 - val_acc: 0.0750
#
# Epoch 00085: val_loss did not improve from 4.78391
# Epoch 86/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.0964 - acc: 0.1272 - val_loss: 4.9885 - val_acc: 0.0558
#
# Epoch 00086: val_loss did not improve from 4.78391
# Epoch 87/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.0802 - acc: 0.1231 - val_loss: 4.8464 - val_acc: 0.0664
#
# Epoch 00087: val_loss did not improve from 4.78391
# Epoch 88/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.0555 - acc: 0.1334 - val_loss: 5.0476 - val_acc: 0.0543
#
# Epoch 00088: val_loss did not improve from 4.78391
# Epoch 89/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.1374 - acc: 0.1225 - val_loss: 4.9868 - val_acc: 0.0637
#
# Epoch 00089: val_loss did not improve from 4.78391
# Epoch 90/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.0288 - acc: 0.1353 - val_loss: 4.9440 - val_acc: 0.0604
#
# Epoch 00090: val_loss did not improve from 4.78391
# Epoch 91/1000
# 100/100 [==============================] - 131s 1s/step - loss: 4.0281 - acc: 0.1331 - val_loss: 5.0177 - val_acc: 0.0611
#
# Epoch 00091: val_loss did not improve from 4.78391
# Epoch 92/1000
# 100/100 [==============================] - 128s 1s/step - loss: 4.0917 - acc: 0.1250 - val_loss: 4.9146 - val_acc: 0.0673
#
# Epoch 00092: val_loss did not improve from 4.78391
# Epoch 93/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.9434 - acc: 0.1478 - val_loss: 5.0131 - val_acc: 0.0586
#
# Epoch 00093: val_loss did not improve from 4.78391
# Epoch 94/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.0903 - acc: 0.1250 - val_loss: 4.8399 - val_acc: 0.0725
#
# Epoch 00094: val_loss did not improve from 4.78391
# Epoch 95/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.9723 - acc: 0.1325 - val_loss: 4.8974 - val_acc: 0.0697
#
# Epoch 00095: val_loss did not improve from 4.78391
# Epoch 96/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.9718 - acc: 0.1475 - val_loss: 5.0065 - val_acc: 0.0601
#
# Epoch 00096: val_loss did not improve from 4.78391
# Epoch 97/1000
# 100/100 [==============================] - 129s 1s/step - loss: 4.0714 - acc: 0.1231 - val_loss: 4.9204 - val_acc: 0.0673
#
# Epoch 00097: val_loss did not improve from 4.78391
# Epoch 98/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.8891 - acc: 0.1537 - val_loss: 4.8605 - val_acc: 0.0669
#
# Epoch 00098: val_loss did not improve from 4.78391
# Epoch 99/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.9986 - acc: 0.1344 - val_loss: 5.1412 - val_acc: 0.0537
#
# Epoch 00099: val_loss did not improve from 4.78391
# Epoch 100/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.9369 - acc: 0.1437 - val_loss: 5.2620 - val_acc: 0.0523
#
# Epoch 00100: val_loss did not improve from 4.78391
# Epoch 101/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.9511 - acc: 0.1453 - val_loss: 5.1971 - val_acc: 0.0497
#
# Epoch 00101: val_loss did not improve from 4.78391
# Epoch 102/1000
# 100/100 [==============================] - 130s 1s/step - loss: 4.0098 - acc: 0.1375 - val_loss: 4.9518 - val_acc: 0.0637
#
# Epoch 00102: val_loss did not improve from 4.78391
# Epoch 103/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.8397 - acc: 0.1553 - val_loss: 5.3027 - val_acc: 0.0543
#
# Epoch 00103: val_loss did not improve from 4.78391
# Epoch 104/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.9638 - acc: 0.1428 - val_loss: 4.8922 - val_acc: 0.0775
#
# Epoch 00104: val_loss did not improve from 4.78391
# Epoch 105/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.9029 - acc: 0.1534 - val_loss: 4.8809 - val_acc: 0.0708
#
# Epoch 00105: val_loss did not improve from 4.78391
# Epoch 106/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.8753 - acc: 0.1491 - val_loss: 4.9815 - val_acc: 0.0708
#
# Epoch 00106: val_loss did not improve from 4.78391
# Epoch 107/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.9751 - acc: 0.1406 - val_loss: 5.3341 - val_acc: 0.0483
#
# Epoch 00107: val_loss did not improve from 4.78391
# Epoch 108/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.8138 - acc: 0.1494 - val_loss: 4.8251 - val_acc: 0.0740
#
# Epoch 00108: val_loss did not improve from 4.78391
# Epoch 109/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.8732 - acc: 0.1559 - val_loss: 5.0016 - val_acc: 0.0669
#
# Epoch 00109: val_loss did not improve from 4.78391
# Epoch 110/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.8603 - acc: 0.1625 - val_loss: 5.2170 - val_acc: 0.0604
#
# Epoch 00110: val_loss did not improve from 4.78391
# Epoch 111/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.8311 - acc: 0.1562 - val_loss: 5.0195 - val_acc: 0.0627
#
# Epoch 00111: val_loss did not improve from 4.78391
# Epoch 112/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.9548 - acc: 0.1450 - val_loss: 4.8102 - val_acc: 0.0787
#
# Epoch 00112: val_loss did not improve from 4.78391
# Epoch 113/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.7707 - acc: 0.1700 - val_loss: 4.9123 - val_acc: 0.0657
#
# Epoch 00113: val_loss did not improve from 4.78391
# Epoch 114/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.8379 - acc: 0.1519 - val_loss: 4.9742 - val_acc: 0.0718
#
# Epoch 00114: val_loss did not improve from 4.78391
# Epoch 115/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.8614 - acc: 0.1584 - val_loss: 5.0391 - val_acc: 0.0563
#
# Epoch 00115: val_loss did not improve from 4.78391
# Epoch 116/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.7778 - acc: 0.1669 - val_loss: 5.0173 - val_acc: 0.0668
#
# Epoch 00116: val_loss did not improve from 4.78391
# Epoch 117/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.8801 - acc: 0.1556 - val_loss: 4.8632 - val_acc: 0.0755
#
# Epoch 00117: val_loss did not improve from 4.78391
# Epoch 118/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.7422 - acc: 0.1700 - val_loss: 5.2968 - val_acc: 0.0574
#
# Epoch 00118: val_loss did not improve from 4.78391
# Epoch 119/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.7781 - acc: 0.1597 - val_loss: 4.9573 - val_acc: 0.0704
#
# Epoch 00119: val_loss did not improve from 4.78391
# Epoch 120/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.8447 - acc: 0.1566 - val_loss: 5.0095 - val_acc: 0.0634
#
# Epoch 00120: val_loss did not improve from 4.78391
# Epoch 121/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.6973 - acc: 0.1816 - val_loss: 5.1879 - val_acc: 0.0584
#
# Epoch 00121: val_loss did not improve from 4.78391
# Epoch 122/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.8229 - acc: 0.1547 - val_loss: 4.9982 - val_acc: 0.0653
#
# Epoch 00122: val_loss did not improve from 4.78391
# Epoch 123/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.7178 - acc: 0.1728 - val_loss: 4.9789 - val_acc: 0.0636
#
# Epoch 00123: val_loss did not improve from 4.78391
# Epoch 124/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.7673 - acc: 0.1656 - val_loss: 5.0427 - val_acc: 0.0656
# Epoch 00124: val_loss did not improve from 4.78391
# Epoch 125/1000
# 100/100 [==============================] - 127s 1s/step - loss: 3.8136 - acc: 0.1628 - val_loss: 5.0279 - val_acc: 0.0764
#
# Epoch 00125: val_loss did not improve from 4.78391
# Epoch 126/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.6683 - acc: 0.1844 - val_loss: 4.9427 - val_acc: 0.0668
#
# Epoch 00126: val_loss did not improve from 4.78391
# Epoch 127/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.7495 - acc: 0.1706 - val_loss: 5.0108 - val_acc: 0.0659
#
# Epoch 00127: val_loss did not improve from 4.78391
# Epoch 128/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.7478 - acc: 0.1688 - val_loss: 5.0732 - val_acc: 0.0673
#
# Epoch 00128: val_loss did not improve from 4.78391
# Epoch 129/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.6916 - acc: 0.1747 - val_loss: 4.9747 - val_acc: 0.0735
#
# Epoch 00129: val_loss did not improve from 4.78391
# Epoch 130/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.7867 - acc: 0.1675 - val_loss: 8.4795 - val_acc: 0.0137
#
# Epoch 00130: val_loss did not improve from 4.78391
# Epoch 131/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.6232 - acc: 0.1884 - val_loss: 5.2245 - val_acc: 0.0603
#
# Epoch 00131: val_loss did not improve from 4.78391
# Epoch 132/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.7417 - acc: 0.1694 - val_loss: 6.0370 - val_acc: 0.0275
#
# Epoch 00132: val_loss did not improve from 4.78391
# Epoch 133/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.6587 - acc: 0.1856 - val_loss: 5.0234 - val_acc: 0.0725
#
# Epoch 00133: val_loss did not improve from 4.78391
# Epoch 134/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.6424 - acc: 0.1919 - val_loss: 4.9045 - val_acc: 0.0750
#
# Epoch 00134: val_loss did not improve from 4.78391
# Epoch 135/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.7800 - acc: 0.1725 - val_loss: 5.2671 - val_acc: 0.0579
#
# Epoch 00135: val_loss did not improve from 4.78391
# Epoch 136/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.5876 - acc: 0.1934 - val_loss: 5.4549 - val_acc: 0.0524
#
# Epoch 00136: val_loss did not improve from 4.78391
# Epoch 137/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.6974 - acc: 0.1878 - val_loss: 5.0211 - val_acc: 0.0747
#
# Epoch 00137: val_loss did not improve from 4.78391
# Epoch 138/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.6486 - acc: 0.1900 - val_loss: 5.9137 - val_acc: 0.0400
#
# Epoch 00138: val_loss did not improve from 4.78391
# Epoch 139/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.6031 - acc: 0.1919 - val_loss: 4.9771 - val_acc: 0.0755
#
# Epoch 00139: val_loss did not improve from 4.78391
# Epoch 140/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.6535 - acc: 0.1856 - val_loss: 5.0121 - val_acc: 0.0744
#
# Epoch 00140: val_loss did not improve from 4.78391
# Epoch 141/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.5252 - acc: 0.2072 - val_loss: 5.4094 - val_acc: 0.0443
#
# Epoch 00141: val_loss did not improve from 4.78391
# Epoch 142/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.6412 - acc: 0.1881 - val_loss: 5.0644 - val_acc: 0.0715
#
# Epoch 00142: val_loss did not improve from 4.78391
# Epoch 143/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.5998 - acc: 0.1931 - val_loss: 5.1591 - val_acc: 0.0632
#
# Epoch 00143: val_loss did not improve from 4.78391
# Epoch 144/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.5091 - acc: 0.2166 - val_loss: 5.2927 - val_acc: 0.0566
#
# Epoch 00144: val_loss did not improve from 4.78391
# Epoch 145/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.6214 - acc: 0.1975 - val_loss: 4.9619 - val_acc: 0.0658
#
# Epoch 00145: val_loss did not improve from 4.78391
# Epoch 146/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.5129 - acc: 0.2078 - val_loss: 5.0387 - val_acc: 0.0764
#
# Epoch 00146: val_loss did not improve from 4.78391
# Epoch 147/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.5980 - acc: 0.1991 - val_loss: 4.9595 - val_acc: 0.0779
#
# Epoch 00147: val_loss did not improve from 4.78391
# Epoch 148/1000
# 100/100 [==============================] - 127s 1s/step - loss: 3.6444 - acc: 0.1888 - val_loss: 5.0414 - val_acc: 0.0670
#
# Epoch 00148: val_loss did not improve from 4.78391
# Epoch 149/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.4751 - acc: 0.2159 - val_loss: 5.1042 - val_acc: 0.0747
#
# Epoch 00149: val_loss did not improve from 4.78391
# Epoch 150/1000
# 100/100 [==============================] - 132s 1s/step - loss: 3.6227 - acc: 0.1772 - val_loss: 4.9942 - val_acc: 0.0797
#
# Epoch 00150: val_loss did not improve from 4.78391
# Epoch 151/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.5184 - acc: 0.1978 - val_loss: 5.4319 - val_acc: 0.0582
#
# Epoch 00151: val_loss did not improve from 4.78391
# Epoch 152/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.5322 - acc: 0.2044 - val_loss: 5.0605 - val_acc: 0.0730
#
# Epoch 00152: val_loss did not improve from 4.78391
# Epoch 153/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.6496 - acc: 0.1925 - val_loss: 5.0103 - val_acc: 0.0732
#
# Epoch 00153: val_loss did not improve from 4.78391
# Epoch 154/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.4168 - acc: 0.2172 - val_loss: 5.1235 - val_acc: 0.0627
#
# Epoch 00154: val_loss did not improve from 4.78391
# Epoch 155/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.4967 - acc: 0.2075 - val_loss: 5.0775 - val_acc: 0.0715
#
# Epoch 00155: val_loss did not improve from 4.78391
# Epoch 156/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.5134 - acc: 0.2116 - val_loss: 5.1541 - val_acc: 0.0702
#
# Epoch 00156: val_loss did not improve from 4.78391
# Epoch 157/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.4966 - acc: 0.2078 - val_loss: 5.4381 - val_acc: 0.0594
#
# Epoch 00157: val_loss did not improve from 4.78391
# Epoch 158/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.5669 - acc: 0.2022 - val_loss: 4.9242 - val_acc: 0.0802
#
# Epoch 00158: val_loss did not improve from 4.78391
# Epoch 159/1000
# 100/100 [==============================] - 128s 1s/step - loss: 3.4066 - acc: 0.2334 - val_loss: 5.0676 - val_acc: 0.0834
#
# Epoch 00159: val_loss did not improve from 4.78391
# Epoch 160/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.5454 - acc: 0.2078 - val_loss: 5.3496 - val_acc: 0.0637
#
# Epoch 00160: val_loss did not improve from 4.78391
# Epoch 161/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.5356 - acc: 0.2072 - val_loss: 5.0147 - val_acc: 0.0838
#
# Epoch 00161: val_loss did not improve from 4.78391
# Epoch 162/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.4669 - acc: 0.2109 - val_loss: 5.0728 - val_acc: 0.0737
#
# Epoch 00162: val_loss did not improve from 4.78391
# Epoch 163/1000
# 100/100 [==============================] - 129s 1s/step - loss: 3.5429 - acc: 0.2166 - val_loss: 5.1873 - val_acc: 0.0708
#
# Epoch 00163: val_loss did not improve from 4.78391
# Epoch 164/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.3785 - acc: 0.2281 - val_loss: 5.2433 - val_acc: 0.0678
#
# Epoch 00164: val_loss did not improve from 4.78391
# Epoch 165/1000
# 100/100 [==============================] - 131s 1s/step - loss: 3.4328 - acc: 0.2172 - val_loss: 5.0780 - val_acc: 0.0687
#
# Epoch 00165: val_loss did not improve from 4.78391
# Epoch 166/1000
# 100/100 [==============================] - 134s 1s/step - loss: 3.4360 - acc: 0.2197 - val_loss: 5.2405 - val_acc: 0.0717
#
# Epoch 00166: val_loss did not improve from 4.78391
# Epoch 167/1000
# 100/100 [==============================] - 130s 1s/step - loss: 3.3199 - acc: 0.2344 - val_loss: 5.2816 - val_acc: 0.0626
#
# Epoch 00167: val_loss did not improve from 4.78391
# Epoch 168/1000
#  13/100 [==>...........................] - ETA: 10s - loss: 3.4997 - acc: 0.1923
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7f7b49eb9f74> in <module>
#      16           validation_data=test_data,
#      17           validation_steps=251,
# ---> 18           callbacks=[checkpointer])
#      19 # model.fit(train_data, test_data,
#      20 #                   callbacks = [checkpointer],
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
vals = pd.DataFrame.from_dict(Saving.history)
vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
vals.head(n=31)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7236ed9c2b3a> in <module>
#       1
# ----> 2 vals = pd.DataFrame.from_dict(Saving.history)
#       3 vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
#       4 vals.head(n=31)
#
# NameError: name 'Saving' is not defined

# %%
import seaborn as sns
sns.set_style({'xtick.bottom':False,
               'ytick.left':False,
               'axes.spines.bottom': False,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False})

ig,(ax,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(20,20))
sns.scatterplot(x='epochs',y='acc',data=vals,ax=ax,color='r')
sns.lineplot(x='epochs',y='val_acc',data=vals,ax=ax,color='g')
sns.scatterplot(x='epochs',y='loss',data=vals,ax=ax1,color='r')
sns.lineplot(x='epochs',y='val_loss',data=vals,ax=ax1,color='g')
ax.legend(labels=['Test Accuracy','Training Accuracy'])
ax1.legend(labels=['Test Loss','Training Loss'])

# %%
# for i in range(n_iterations):
#         print('\r{}/{}'. format(i, n_iterations))
#         #initilaize random hyperparameters
#         random_parameters = {K: random.sample(V, 1)[0] for K, V in parameters_grid.items()}
#         #create model with random hyperparameters
#         model = create_model(random_parameters)
#         opt = create_RMSprop_optimizer(random_parameters)
#         #compile model
#         model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])
#         #train model
#         epochs = 40
#         checkpointer = ModelCheckpoint(filepath='saved_models/model_weights.hdf5', verbose=1, save_best_only=True)
#         early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 8)
#         history = model.fit(X_train, Y_train,
#                   callbacks = [checkpointer, early_stopping],
#                   validation_split = 0.33,
#                   epochs=epochs, batch_size = 20, verbose=1)
#         #compare current min validation loss with global min validation loss
#         current_min_val_loss = np.min(history.history['val_loss'])
#         if(current_min_val_loss < global_min_val_loss):
#             global_min_val_loss = current_min_val_loss
#             #save the best model so far
#             model.load_weights('saved_models/model_weights.hdf5')
#             model.save('saved_models/best_model.h5')
#             print('saving new best model, val_loss = {}'.format(current_min_val_loss))
#             #save best hyperparameters
#             best_hyperparameters = random_parameters
