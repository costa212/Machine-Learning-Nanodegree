# %% [markdown]
# # Car Make and Model Recognizer
# I shall explore here my tries to reach a good optimizer

# %% [markdown]
# ## Importing Libraries

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from glob import glob
from keras import regularizers
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Pre-Processing
#
# ### Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.25,
                                   rotation_range = 90,
                                   horizontal_flip=True,
                                  validation_split = 0.3)
#test_datagen = ImageDataGenerator(rescale=1./255,
 #                                horizontal_flip = True)

train_data = train_datagen.flow_from_directory('My_Cars/trainCropped',
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='training')
test_data = train_datagen.flow_from_directory('My_Cars/trainCropped',
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                            subset='validation',
                                            shuffle=True)
# Out:
# Found 5796 images belonging to 196 classes.
# Found 2348 images belonging to 196 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(filters=64, kernel_size=4, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l2(0.0005), bias_regularizer=regularizers.l2(0.0005)))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu')) 
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv2D(filters=256, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.35))

model.add(Conv2D(filters=512, kernel_size=2, strides=1,kernel_initializer = 'random_normal', padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.6))

model.add(Conv2D(filters=512, kernel_size=2, strides=1,kernel_initializer = 'random_normal',padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(BatchNormalization())
model.add(Dropout(0.9))

model.add(GlobalAveragePooling2D())
model.add(Dense(196, activation='softmax'))

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 224, 224, 64)      3136
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 112, 128)     32896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 256)       131328
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       524800
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       1049088
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 1,847,684
# Trainable params: 1,844,740
# Non-trainable params: 2,944
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 200

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='Saved_Models/weights.best.from_scratch29.hdf5', 
                               verbose=1, save_best_only=True)

Saving = model.fit_generator(train_data,
          steps_per_epoch=185,  
          epochs=epochs,
          verbose=1, 
          validation_data=test_data,
          validation_steps=100,
          callbacks=[checkpointer])
# model.fit(train_data, test_data,
#                   callbacks = [checkpointer],
#                   validation_split = 0.33,
#                   epochs=epochs,
#           batch_size = 20,
#           verbose=1)
# Out:
# Epoch 1/200
# 185/185 [==============================] - 130s 702ms/step - loss: 5.4042 - acc: 0.0066 - val_loss: 5.7683 - val_acc: 0.0060
#
# Epoch 00001: val_loss improved from inf to 5.76828, saving model to Saved_Models/weights.best.from_scratch29.hdf5
# Epoch 2/200
# 185/185 [==============================] - 125s 676ms/step - loss: 5.3181 - acc: 0.0081 - val_loss: 5.7008 - val_acc: 0.0031
#
# Epoch 00002: val_loss improved from 5.76828 to 5.70084, saving model to Saved_Models/weights.best.from_scratch29.hdf5
# Epoch 3/200
# 185/185 [==============================] - 122s 659ms/step - loss: 5.2820 - acc: 0.0127 - val_loss: 5.7131 - val_acc: 0.0038
#
# Epoch 00003: val_loss did not improve from 5.70084
# Epoch 4/200
# 185/185 [==============================] - 125s 677ms/step - loss: 5.2487 - acc: 0.0110 - val_loss: 5.7267 - val_acc: 0.0050
#
# Epoch 00004: val_loss did not improve from 5.70084
# Epoch 5/200
# 185/185 [==============================] - 134s 727ms/step - loss: 5.2157 - acc: 0.0144 - val_loss: 5.7683 - val_acc: 0.0072
#
# Epoch 00005: val_loss did not improve from 5.70084
# Epoch 6/200
# 185/185 [==============================] - 124s 671ms/step - loss: 5.1873 - acc: 0.0162 - val_loss: 5.7244 - val_acc: 0.0063
#
# Epoch 00006: val_loss did not improve from 5.70084
# Epoch 7/200
# 185/185 [==============================] - 123s 664ms/step - loss: 5.1824 - acc: 0.0169 - val_loss: 5.8073 - val_acc: 0.0057
#
# Epoch 00007: val_loss did not improve from 5.70084
# Epoch 8/200
# 185/185 [==============================] - 123s 665ms/step - loss: 5.1688 - acc: 0.0188 - val_loss: 5.8037 - val_acc: 0.0069
#
# Epoch 00008: val_loss did not improve from 5.70084
# Epoch 9/200
# 185/185 [==============================] - 124s 671ms/step - loss: 5.1467 - acc: 0.0179 - val_loss: 5.8568 - val_acc: 0.0082
#
# Epoch 00009: val_loss did not improve from 5.70084
# Epoch 10/200
# 185/185 [==============================] - 123s 665ms/step - loss: 5.1340 - acc: 0.0242 - val_loss: 5.8665 - val_acc: 0.0094
#
# Epoch 00010: val_loss did not improve from 5.70084
# Epoch 11/200
# 185/185 [==============================] - 123s 664ms/step - loss: 5.1174 - acc: 0.0208 - val_loss: 5.8671 - val_acc: 0.0072
#
# Epoch 00011: val_loss did not improve from 5.70084
# Epoch 12/200
# 185/185 [==============================] - 123s 663ms/step - loss: 5.0963 - acc: 0.0245 - val_loss: 5.9720 - val_acc: 0.0073
#
# Epoch 00012: val_loss did not improve from 5.70084
# Epoch 13/200
# 185/185 [==============================] - 125s 673ms/step - loss: 5.0892 - acc: 0.0294 - val_loss: 5.9525 - val_acc: 0.0091
#
# Epoch 00013: val_loss did not improve from 5.70084
# Epoch 14/200
# 185/185 [==============================] - 124s 668ms/step - loss: 5.0830 - acc: 0.0211 - val_loss: 5.9381 - val_acc: 0.0085
#
# Epoch 00014: val_loss did not improve from 5.70084
# Epoch 15/200
# 185/185 [==============================] - 122s 661ms/step - loss: 5.0712 - acc: 0.0265 - val_loss: 5.9232 - val_acc: 0.0117
#
# Epoch 00015: val_loss did not improve from 5.70084
# Epoch 16/200
# 185/185 [==============================] - 123s 663ms/step - loss: 5.0611 - acc: 0.0263 - val_loss: 5.9266 - val_acc: 0.0116
#
# Epoch 00016: val_loss did not improve from 5.70084
# Epoch 17/200
# 185/185 [==============================] - 123s 667ms/step - loss: 5.0334 - acc: 0.0247 - val_loss: 5.9146 - val_acc: 0.0119
#
# Epoch 00017: val_loss did not improve from 5.70084
# Epoch 18/200
# 185/185 [==============================] - 123s 667ms/step - loss: 5.0467 - acc: 0.0270 - val_loss: 5.8853 - val_acc: 0.0101
#
# Epoch 00018: val_loss did not improve from 5.70084
# Epoch 19/200
# 185/185 [==============================] - 124s 670ms/step - loss: 5.0294 - acc: 0.0287 - val_loss: 5.9507 - val_acc: 0.0091
#
# Epoch 00019: val_loss did not improve from 5.70084
# Epoch 20/200
# 185/185 [==============================] - 122s 662ms/step - loss: 5.0106 - acc: 0.0284 - val_loss: 5.9426 - val_acc: 0.0098
#
# Epoch 00020: val_loss did not improve from 5.70084
# Epoch 21/200
# 185/185 [==============================] - 123s 666ms/step - loss: 5.0188 - acc: 0.0306 - val_loss: 5.9630 - val_acc: 0.0097
#
# Epoch 00021: val_loss did not improve from 5.70084
# Epoch 22/200
# 185/185 [==============================] - 123s 663ms/step - loss: 4.9832 - acc: 0.0324 - val_loss: 5.9808 - val_acc: 0.0097
#
# Epoch 00022: val_loss did not improve from 5.70084
# Epoch 23/200
# 185/185 [==============================] - 123s 665ms/step - loss: 4.9829 - acc: 0.0318 - val_loss: 5.8575 - val_acc: 0.0101
#
# Epoch 00023: val_loss did not improve from 5.70084
# Epoch 24/200
# 185/185 [==============================] - 123s 664ms/step - loss: 4.9883 - acc: 0.0299 - val_loss: 5.9808 - val_acc: 0.0091
#
# Epoch 00024: val_loss did not improve from 5.70084
# Epoch 25/200
# 185/185 [==============================] - 123s 665ms/step - loss: 4.9575 - acc: 0.0350 - val_loss: 6.0111 - val_acc: 0.0091
#
# Epoch 00025: val_loss did not improve from 5.70084
# Epoch 26/200
# 185/185 [==============================] - 123s 663ms/step - loss: 4.9591 - acc: 0.0351 - val_loss: 5.8751 - val_acc: 0.0098
#
# Epoch 00026: val_loss did not improve from 5.70084
# Epoch 27/200
# 185/185 [==============================] - 124s 670ms/step - loss: 4.9525 - acc: 0.0363 - val_loss: 5.9906 - val_acc: 0.0091
#
# Epoch 00027: val_loss did not improve from 5.70084
# Epoch 28/200
# 185/185 [==============================] - 122s 662ms/step - loss: 4.9466 - acc: 0.0323 - val_loss: 5.8828 - val_acc: 0.0123
#
# Epoch 00028: val_loss did not improve from 5.70084
# Epoch 29/200
# 185/185 [==============================] - 123s 667ms/step - loss: 4.9397 - acc: 0.0341 - val_loss: 5.9330 - val_acc: 0.0114
#
# Epoch 00029: val_loss did not improve from 5.70084
# Epoch 30/200
# 185/185 [==============================] - 123s 665ms/step - loss: 4.9263 - acc: 0.0380 - val_loss: 5.9873 - val_acc: 0.0101
#
# Epoch 00030: val_loss did not improve from 5.70084
# Epoch 31/200
# 185/185 [==============================] - 123s 666ms/step - loss: 4.9344 - acc: 0.0382 - val_loss: 5.9499 - val_acc: 0.0088
#
# Epoch 00031: val_loss did not improve from 5.70084
# Epoch 32/200
# 185/185 [==============================] - 123s 664ms/step - loss: 4.9080 - acc: 0.0400 - val_loss: 5.9616 - val_acc: 0.0085
#
# Epoch 00032: val_loss did not improve from 5.70084
# Epoch 33/200
# 185/185 [==============================] - 123s 665ms/step - loss: 4.8970 - acc: 0.0383 - val_loss: 5.9610 - val_acc: 0.0104
#
# Epoch 00033: val_loss did not improve from 5.70084
# Epoch 34/200
# 185/185 [==============================] - 124s 668ms/step - loss: 4.9006 - acc: 0.0414 - val_loss: 5.9879 - val_acc: 0.0104
#
# Epoch 00034: val_loss did not improve from 5.70084
# Epoch 35/200
# 185/185 [==============================] - 123s 664ms/step - loss: 4.8733 - acc: 0.0448 - val_loss: 6.0099 - val_acc: 0.0079
#
# Epoch 00035: val_loss did not improve from 5.70084
# Epoch 36/200
# 185/185 [==============================] - 124s 669ms/step - loss: 4.8804 - acc: 0.0417 - val_loss: 6.0011 - val_acc: 0.0138
#
# Epoch 00036: val_loss did not improve from 5.70084
# Epoch 37/200
# 185/185 [==============================] - 123s 666ms/step - loss: 4.8922 - acc: 0.0390 - val_loss: 5.9787 - val_acc: 0.0079
#
# Epoch 00037: val_loss did not improve from 5.70084
# Epoch 38/200
# 185/185 [==============================] - 123s 666ms/step - loss: 4.8718 - acc: 0.0394 - val_loss: 5.9698 - val_acc: 0.0138
#
# Epoch 00038: val_loss did not improve from 5.70084
# Epoch 39/200
# 185/185 [==============================] - 123s 667ms/step - loss: 4.8662 - acc: 0.0463 - val_loss: 5.9962 - val_acc: 0.0085
#
# Epoch 00039: val_loss did not improve from 5.70084
# Epoch 40/200
# 185/185 [==============================] - 123s 666ms/step - loss: 4.8563 - acc: 0.0439 - val_loss: 5.9135 - val_acc: 0.0114
#
# Epoch 00040: val_loss did not improve from 5.70084
# Epoch 41/200
# 185/185 [==============================] - 123s 667ms/step - loss: 4.8385 - acc: 0.0422 - val_loss: 5.9223 - val_acc: 0.0126
#
# Epoch 00041: val_loss did not improve from 5.70084
# Epoch 42/200
# 185/185 [==============================] - 123s 666ms/step - loss: 4.8566 - acc: 0.0422 - val_loss: 5.9798 - val_acc: 0.0119
#
# Epoch 00042: val_loss did not improve from 5.70084
# Epoch 43/200
# 185/185 [==============================] - 123s 662ms/step - loss: 4.8329 - acc: 0.0483 - val_loss: 5.9894 - val_acc: 0.0063
#
# Epoch 00043: val_loss did not improve from 5.70084
# Epoch 44/200
# 184/185 [============================>.] - ETA: 0s - loss: 4.8190 - acc: 0.0435
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0232a8045a97> in <module>
#      16           validation_data=test_data,
#      17           validation_steps=100,
# ---> 18           callbacks=[checkpointer])
#      19 # model.fit(train_data, test_data,
#      20 #                   callbacks = [checkpointer],
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     232                             val_enqueuer_gen,
#     233                             validation_steps,
# --> 234                             workers=0)
#     235                     else:
#     236                         # No need for try/except because
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1470             workers=workers,
#    1471             use_multiprocessing=use_multiprocessing,
# -> 1472             verbose=verbose)
#    1473
#    1474     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in evaluate_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     344                                  'or (x, y). Found: ' +
#     345                                  str(generator_output))
# --> 346             outs = model.test_on_batch(x, y, sample_weight=sample_weight)
#     347             outs = to_list(outs)
#     348             outs_per_batch.append(outs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in test_on_batch(self, x, y, sample_weight)
#    1254             ins = x + y + sample_weights
#    1255         self._make_test_function()
# -> 1256         outputs = self.test_function(ins)
#    1257         return unpack_singleton(outputs)
#    1258
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
vals = pd.DataFrame.from_dict(Saving.history)
vals = pd.concat([pd.Series(range(0,100),name='epochs'),vals],axis=1)
vals.head(n=31)

# %%
import seaborn as sns
sns.set_style({'xtick.bottom':False,
               'ytick.left':False,
               'axes.spines.bottom': False,
               'axes.spines.left': False,
               'axes.spines.right': False,
               'axes.spines.top': False})

ig,(ax,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(20,20))
sns.scatterplot(x='epochs',y='acc',data=vals,ax=ax,color='r')
sns.lineplot(x='epochs',y='val_acc',data=vals,ax=ax,color='g')
sns.scatterplot(x='epochs',y='loss',data=vals,ax=ax1,color='r')
sns.lineplot(x='epochs',y='val_loss',data=vals,ax=ax1,color='g')
ax.legend(labels=['Test Accuracy','Training Accuracy'])
ax1.legend(labels=['Test Loss','Training Loss'])

# %%
# for i in range(n_iterations):
#         print('\r{}/{}'. format(i, n_iterations))
#         #initilaize random hyperparameters
#         random_parameters = {K: random.sample(V, 1)[0] for K, V in parameters_grid.items()}
#         #create model with random hyperparameters
#         model = create_model(random_parameters)
#         opt = create_RMSprop_optimizer(random_parameters)
#         #compile model
#         model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])
#         #train model
#         epochs = 40
#         checkpointer = ModelCheckpoint(filepath='saved_models/model_weights.hdf5', verbose=1, save_best_only=True)
#         early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 8)
#         history = model.fit(X_train, Y_train,
#                   callbacks = [checkpointer, early_stopping],
#                   validation_split = 0.33,
#                   epochs=epochs, batch_size = 20, verbose=1)
#         #compare current min validation loss with global min validation loss
#         current_min_val_loss = np.min(history.history['val_loss'])
#         if(current_min_val_loss < global_min_val_loss):
#             global_min_val_loss = current_min_val_loss
#             #save the best model so far
#             model.load_weights('saved_models/model_weights.hdf5')
#             model.save('saved_models/best_model.h5')
#             print('saving new best model, val_loss = {}'.format(current_min_val_loss))
#             #save best hyperparameters
#             best_hyperparameters = random_parameters
